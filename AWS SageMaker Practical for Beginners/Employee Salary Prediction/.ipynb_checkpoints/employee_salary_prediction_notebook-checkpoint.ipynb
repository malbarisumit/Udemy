# %% [markdown]
# # TASK #1: UNDERSTAND THE PROBLEM STATEMENT

# %% [markdown]
# - The objective of this case study is to predict the employee salary based on the number of years of experience.
# - In simple linear regression, we predict the value of one variable Y based on another variable X.
# - X is called the independent variable and Y is called the dependant variable.
# - Why simple? Because it examines relationship between two variables only.
# - Why linear? when the independent variable increases (or decreases), the dependent variable increases (or decreases) in a linear fashion.

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES AND DATASETS

# %%
# install seaborn library
# !pip install seaborn
# !pip install tensorflow
#import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install numpy==1.16.5
# Out:
# /opt/conda/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting numpy==1.16.5
#   Downloading numpy-1.16.5-cp37-cp37m-manylinux1_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 4.7 MB/s eta 0:00:01     |█████████████████████████████▌  | 16.0 MB 4.7 MB/s eta 0:00:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyarrow 4.0.0 requires numpy>=1.16.6, but you have numpy 1.16.5 which is incompatible.
# Successfully installed numpy-1.18.1
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.

# %%
print(np.__version__)
# Out:
# 1.19.5

# %%
# !pip3 install numpy==1.19.5
# Out:
# /opt/conda/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting numpy==1.19.5
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 5.7 MB/s eta 0:00:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.1
#     Uninstalling numpy-1.18.1:
#       Successfully uninstalled numpy-1.18.1
# Successfully installed numpy-1.19.5
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 1.20.3

# %%
# read the csv file 
salary_df = pd.read_csv('salary.csv')

# %%
salary_df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# 32             12.3  128765
# 33             12.9  135675
# 34             13.5  139465

# %% [markdown]
# MINI CHALLENGE
#  - Use head and tail methods to print the first and last 7 rows of the dataframe
#  - Try to find the maximum salary value in the dataframe

# %%
salary_df.head(7)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
# 5              2.9   56642
# 6              3.0   60150

# %%
salary_df.tail(7)
# Out:
#     YearsExperience  Salary
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# 32             12.3  128765
# 33             12.9  135675
# 34             13.5  139465

# %%
salary_df['Salary'].max()
# Out:
# 139465

# %% [markdown]
# # TASK #3: PERFORM EXPLORATORY DATA ANALYSIS AND VISUALIZATION

# %%
# check if there are any Null values
sns.heatmap(salary_df.isnull(), yticklabels = False, cbar = False, cmap="Blues")

# %%
# Check the dataframe info

salary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  35 non-null     float64
#  1   Salary           35 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 688.0 bytes

# %%
# Statistical summary of the dataframe

salary_df.describe()
# Out:
#        YearsExperience         Salary
# count        35.000000      35.000000
# mean          6.308571   83945.600000
# std           3.618610   32162.673003
# min           1.100000   37731.000000
# 25%           3.450000   57019.000000
# 50%           5.300000   81363.000000
# 75%           9.250000  113223.500000
# max          13.500000  139465.000000

# %% [markdown]
# MINI CHALLENGE
#  - What are the number of years of experience corresponding to employees with minimum and maximim salaries?

# %%
max = salary_df[salary_df["Salary"]==salary_df["Salary"].max()]

# %%
max
# Out:
#     YearsExperience  Salary
# 34             13.5  139465

# %%
min = salary_df[salary_df["Salary"]==salary_df["Salary"].min()]

# %%
min
# Out:
#    YearsExperience  Salary
# 2              1.5   37731

# %%
salary_df.hist(bins = 30, figsize = (20,10), color = 'r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faa2a4b0350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faa29c60950>]],
#       dtype=object)

# %%
# plot pairplot

sns.pairplot(salary_df)

# %%
corr_matrix = salary_df.corr()
sns.heatmap(corr_matrix, annot = True)
plt.show()

# %% [markdown]
# MINI CHALLENGE
# - Use regplot in Seaborn to obtain a straight line fit between "salary" and "years of experience"

# %%
sns.regplot(x='YearsExperience', y='Salary', data=salary_df)

# %% [markdown]
# # TASK #4: CREATE TRAINING AND TESTING DATASET

# %%
X = salary_df[['YearsExperience']]
y = salary_df[['Salary']]

# %%
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5
# 30             11.2
# 31             11.5
# 32             12.3
# 33             12.9
# 34             13.5

# %%
y
# Out:
#     Salary
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# 10   63218
# 11   55794
# 12   56957
# 13   57081
# 14   61111
# 15   67938
# 16   66029
# 17   83088
# 18   81363
# 19   93940
# 20   91738
# 21   98273
# 22  101302
# 23  113812
# 24  109431
# 25  105582
# 26  116969
# 27  112635
# 28  122391
# 29  121872
# 30  127345
# 31  126756
# 32  128765
# 33  135675
# 34  139465

# %%
X.shape
# Out:
# (35, 1)

# %%
y.shape
# Out:
# (35, 1)

# %%
X = np.array(X).astype('float32')
y = np.array(y).astype('float32')

# %%
# Only take the numerical variables and scale them
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5],
#        [11.2],
#        [11.5],
#        [12.3],
#        [12.9],
#        [13.5]], dtype=float32)

# %%
# split the data into test and train sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (28, 1)

# %%
X_test.shape
# Out:
# (7, 1)

# %%
X_train
# Out:
# array([[ 4.5],
#        [13.5],
#        [ 7.9],
#        [ 2.2],
#        [ 6. ],
#        [ 4. ],
#        [ 5.1],
#        [ 4. ],
#        [ 6.8],
#        [ 5.9],
#        [10.3],
#        [ 1.3],
#        [ 9.5],
#        [ 9. ],
#        [ 3. ],
#        [ 2.9],
#        [11.2],
#        [ 9.6],
#        [ 8.2],
#        [10.5],
#        [11.5],
#        [ 4.1],
#        [ 4.9],
#        [ 3.9],
#        [ 7.1],
#        [ 1.1],
#        [ 3.2],
#        [ 3.2]], dtype=float32)

# %% [markdown]
# MINI CHALLENGE
#  - Try splitting the data into 75% for training and the rest for testing
#  - Verify that the split was successful by obtaining the shape of both X_train and X_test
#  - Did you notice any change in the order of the data? why?

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
X_train.shape
# Out:
# (26, 1)

# %%
X_test.shape
# Out:
# (9, 1)

# %%
X_train
# Out:
# array([[ 4. ],
#        [ 2.2],
#        [13.5],
#        [ 4.9],
#        [ 9.6],
#        [ 3.9],
#        [ 2. ],
#        [ 3.2],
#        [ 5.9],
#        [ 7.9],
#        [10.3],
#        [ 1.5],
#        [ 4.5],
#        [ 4. ],
#        [ 3. ],
#        [ 9. ],
#        [ 1.1],
#        [10.5],
#        [ 8.2],
#        [11.2],
#        [ 4.1],
#        [ 1.3],
#        [ 6. ],
#        [ 3.2],
#        [ 9.5],
#        [ 8.7]], dtype=float32)

# %% [markdown]
# # TASK #5: TRAIN A LINEAR REGRESSION MODEL IN SK-LEARN (NOTE THAT SAGEMAKER BUILT-IN ALGORITHMS ARE NOT USED HERE)

# %%
# using linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score

regresssion_model_sklearn = LinearRegression(fit_intercept = True)
regresssion_model_sklearn.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regresssion_model_sklearn_accuracy = regresssion_model_sklearn.score(X_test, y_test)
regresssion_model_sklearn_accuracy
# Out:
# 0.9520268323078759

# %%
print('Linear Model Coefficient (m): ', regresssion_model_sklearn.coef_)
print('Linear Model Coefficient (b): ', regresssion_model_sklearn.intercept_)
# Out:
# Linear Model Coefficient (m):  [[9014.646]]
# Linear Model Coefficient (b):  [27419.125]

# %% [markdown]
# MINI CHALLENGE
# - Retrain the model while setting the fit_intercept = False, what do you notice?

# %%
regresssion_model_sklearn = LinearRegression(fit_intercept = False)
regresssion_model_sklearn.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=False, n_jobs=None, normalize=False)

# %%
regresssion_model_sklearn_accuracy = regresssion_model_sklearn.score(X_test, y_test)
regresssion_model_sklearn_accuracy
# Out:
# 0.6753318952322278

# %%
print('Linear Model Coefficient (m): ', regresssion_model_sklearn.coef_)
print('Linear Model Coefficient (b): ', regresssion_model_sklearn.intercept_)
# Out:
# Linear Model Coefficient (m):  [[12470.971]]
# Linear Model Coefficient (b):  0.0

# %% [markdown]
# # TASK #6: EVALUATE TRAINED MODEL PERFORMANCE (NOTE THAT SAGEMAKER BUILT-IN ALGORITHMS ARE NOT USED HERE)

# %%
y_predict = regresssion_model_sklearn.predict(X_test)

# %%
y_predict
# Out:
# array([[131087.56 ],
#        [ 73393.82 ],
#        [ 88718.72 ],
#        [ 91423.11 ],
#        [ 75196.75 ],
#        [ 53561.6  ],
#        [143708.06 ],
#        [138299.28 ],
#        [ 60773.316]], dtype=float32)

# %%
plt.scatter(X_train, y_train, color = 'gray')
plt.plot(X_train, regresssion_model_sklearn.predict(X_train), color = 'red')
plt.ylabel('Salary')
plt.xlabel('Number of Years of Experience')
plt.title('Salary vs. Years of Experience')
# Out:
# Text(0.5, 1.0, 'Salary vs. Years of Experience')

# %% [markdown]
# MINI CHALLENGE
#  - Use the trained model, obtain the salary corresponding to eployees who have years of experience = 5

# %%
x_5 = [[5]]

# %%
y_5 = regresssion_model_sklearn.predict(x_5)

# %%
y_5
# Out:
# array([[72492.35742188]])

# %% [markdown]
# # TASK #7: TRAIN A LINEAR LEARNER MODEL USING SAGEMAKER

# %%
# Boto3 is the Amazon Web Services (AWS) Software Development Kit (SDK) for Python
# Boto3 allows Python developer to write software that makes use of services like Amazon S3 and Amazon EC2

import sagemaker
import boto3
from sagemaker import Session

# Let's create a Sagemaker session
sagemaker_session = sagemaker.Session()
bucket = Session().default_bucket()
# Let's define the S3 bucket and prefix that we want to use in this session
bucket = 'sagemaker-sumitpractice' # bucket named 'sagemaker-practical' was created beforehand
prefix = 'linear_learner' # prefix is the subfolder within the bucket.

# Let's get the execution role for the notebook instance. 
# This is the IAM role that you created when you created your notebook instance. You pass the role to the training job.
# Note that AWS Identity and Access Management (IAM) role that Amazon SageMaker can assume to perform tasks on your behalf (for example, reading training results, called model artifacts, from the S3 bucket and writing training results to Amazon S3). 
role = sagemaker.get_execution_role()
print(role)
# Out:
# arn:aws:iam::345479476747:role/service-role/AmazonSageMaker-ExecutionRole-20210602T011143

# %%
X_train.shape
# Out:
# (26, 1)

# %%
y_train = y_train[:,0]

# %%
y_train.shape
# Out:
# (26,)

# %%
import io # The io module allows for dealing with various types of I/O (text I/O, binary I/O and raw I/O). 
import numpy as np
import sagemaker.amazon.common as smac # sagemaker common libary

# Code below converts the data in numpy array format to RecordIO format
# This is the format required by Sagemaker Linear Learner 

buf = io.BytesIO() # create an in-memory byte array (buf is a buffer I will be writing to)
smac.write_numpy_to_dense_tensor(buf, X_train, y_train)
buf.seek(0) 
# When you write to in-memory byte arrays, it increments 1 every time you write to it
# Let's reset that back to zero
# Out:
# 0

# %%
import os

# Code to upload RecordIO data to S3
 
# Key refers to the name of the file    
key = 'linear-train-data'

# The following code uploads the data in record-io format to S3 bucket to be accessed later for training
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)

# Let's print out the training data location in s3
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
print('uploaded training data location: {}'.format(s3_train_data))
# Out:
# uploaded training data location: s3://sagemaker-sumitpractice/linear_learner/train/linear-train-data

# %%
X_test.shape
# Out:
# (9, 1)

# %%
y_test.shape
# Out:
# (9, 1)

# %%
# Make sure that the target label is a vector
y_test = y_test[:,0]

# %%
y_test
# Out:
# array([126756.,  66029.,  91738.,  98273.,  83088.,  56642., 135675.,
#        128765.,  57189.], dtype=float32)

# %%
# Code to upload RecordIO data to S3

buf = io.BytesIO() # create an in-memory byte array (buf is a buffer I will be writing to)
smac.write_numpy_to_dense_tensor(buf, X_test, y_test)
buf.seek(0) 
# When you write to in-memory byte arrays, it increments 1 every time you write to it
# Let's reset that back to zero
# Out:
# 0

# %%
# Key refers to the name of the file    
key = 'linear-test-data'

# The following code uploads the data in record-io format to S3 bucket to be accessed later for training
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'test', key)).upload_fileobj(buf)

# Let's print out the testing data location in s3
s3_test_data = 's3://{}/{}/test/{}'.format(bucket, prefix, key)
print('uploaded training data location: {}'.format(s3_test_data))
# Out:
# uploaded training data location: s3://sagemaker-sumitpractice/linear_learner/test/linear-test-data

# %%
# create an output placeholder in S3 bucket to store the linear learner output

output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('Training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# Training artifacts will be uploaded to: s3://sagemaker-us-east-2-542063182511/linear_learner/output

# %%
output_location = 's3://{}/{}/output'.format(bucket,prefix)
print('Training artifacts will be uploaded to:{}'.format(output_location))
# Out:
# Training artifacts will be uploaded to:s3://sagemaker-sumitpractice/linear_learner/output

# %%
# This code is used to get the training container of sagemaker built-in algorithms
# all we have to do is to specify the name of the algorithm, that we want to use

# Let's obtain a reference to the linearLearner container image
# Note that all regression models are named estimators
# You don't have to specify (hardcode) the region, get_image_uri will get the current region name using boto3.Session

from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(boto3.Session().region_name, 'linear-learner')
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.

# %%
# We have pass in the container, the type of instance that we would like to use for training 
# output path and sagemaker session into the Estimator. 
# We can also specify how many instances we would like to use for training
# sagemaker_session = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count = 1, 
                                       train_instance_type = 'ml.c4.xlarge',
                                       output_path = output_location,
                                       sagemaker_session = sagemaker_session)


# We can tune parameters like the number of features that we are passing in, type of predictor like 'regressor' or 'classifier', mini batch size, epochs
# Train 32 different versions of the model and will get the best out of them (built-in parameters optimization!)

linear.set_hyperparameters(feature_dim = 1,
                           predictor_type = 'regressor',
                           mini_batch_size = 5,
                           epochs = 5,
                           num_models = 32,
                           loss = 'absolute_loss')

# Now we are ready to pass in the training data from S3 to train the linear learner model

linear.fit({'train': s3_train_data})

# Let's see the progress using cloudwatch logs
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-06-02 07:48:22 Starting - Starting the training job...
# 2021-06-02 07:48:24 Starting - Launching requested ML instancesProfilerReport-1622620102: InProgress
# ......
# 2021-06-02 07:49:48 Starting - Preparing the instances for training......
# 2021-06-02 07:50:48 Downloading - Downloading input data...
# 2021-06-02 07:51:22 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [06/02/2021 07:51:27 INFO 139899957315392] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [06/02/2021 07:51:27 INFO 139899957315392] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'loss': 'absolute_loss', 'feature_dim': '1', 'num_models': '32', 'predictor_type': 'regressor', 'epochs': '5', 'mini_batch_size': '5'}
# [06/02/2021 07:51:27 INFO 139899957315392] Final configuration: {'mini_batch_size': '5', 'epochs': '5', 'feature_dim': '1', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '32', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'absolute_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [06/02/2021 07:51:27 WARNING 139899957315392] Loggers have already been setup.
# Process 1 is a worker.
# [06/02/2021 07:51:27 INFO 139899957315392] Using default worker.
# [06/02/2021 07:51:27 INFO 139899957315392] Checkpoint loading and saving are disabled.
# [2021-06-02 07:51:27.340] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 14, "num_examples": 1, "num_bytes": 240}
# [06/02/2021 07:51:27 INFO 139899957315392] Create Store: local
# [2021-06-02 07:51:27.400] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 59, "num_examples": 6, "num_bytes": 1248}
# [06/02/2021 07:51:27 INFO 139899957315392] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f3c9f65c710>
# [06/02/2021 07:51:27 INFO 139899957315392] Scaling model computed with parameters:
#  {'stdev_label':
# [31895.934]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [3.4896421]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [79380.4]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [5.7799997]
# <NDArray 1 @cpu(0)>}
# [06/02/2021 07:51:27 INFO 139899957315392] nvidia-smi: took 0.032 seconds to run.
# [06/02/2021 07:51:27 INFO 139899957315392] nvidia-smi identified 0 GPUs.
# [06/02/2021 07:51:27 INFO 139899957315392] Number of GPUs being used: 0
# #metrics {"StartTime": 1622620287.527001, "EndTime": 1622620287.5270545, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Total Batches Seen": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-06-02 07:51:27.662] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 134, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620287.6624372, "EndTime": 1622620287.6625183, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8945285511016846, "count": 1, "min": 0.8945285511016846, "max": 0.8945285511016846}}}
#
# #metrics {"StartTime": 1622620287.662603, "EndTime": 1622620287.662624, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9145934009552001, "count": 1, "min": 0.9145934009552001, "max": 0.9145934009552001}}}
#
# #metrics {"StartTime": 1622620287.6626778, "EndTime": 1622620287.6626961, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8969591331481933, "count": 1, "min": 0.8969591331481933, "max": 0.8969591331481933}}}
#
# #metrics {"StartTime": 1622620287.6627502, "EndTime": 1622620287.662768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9135679912567138, "count": 1, "min": 0.9135679912567138, "max": 0.9135679912567138}}}
#
# #metrics {"StartTime": 1622620287.6628227, "EndTime": 1622620287.6628404, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7887770366668702, "count": 1, "min": 0.7887770366668702, "max": 0.7887770366668702}}}
#
# #metrics {"StartTime": 1622620287.6628923, "EndTime": 1622620287.66291, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7973329544067382, "count": 1, "min": 0.7973329544067382, "max": 0.7973329544067382}}}
#
# #metrics {"StartTime": 1622620287.6629639, "EndTime": 1622620287.6629803, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8596661376953125, "count": 1, "min": 0.8596661376953125, "max": 0.8596661376953125}}}
#
# #metrics {"StartTime": 1622620287.6630332, "EndTime": 1622620287.6630502, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8193386936187744, "count": 1, "min": 0.8193386936187744, "max": 0.8193386936187744}}}
#
# #metrics {"StartTime": 1622620287.6631036, "EndTime": 1622620287.6631207, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9508654689788818, "count": 1, "min": 0.9508654689788818, "max": 0.9508654689788818}}}
#
# #metrics {"StartTime": 1622620287.6631727, "EndTime": 1622620287.6631887, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8824044704437256, "count": 1, "min": 0.8824044704437256, "max": 0.8824044704437256}}}
#
# #metrics {"StartTime": 1622620287.6632397, "EndTime": 1622620287.6632562, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8891557693481446, "count": 1, "min": 0.8891557693481446, "max": 0.8891557693481446}}}
#
# #metrics {"StartTime": 1622620287.6633089, "EndTime": 1622620287.6633258, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.874226713180542, "count": 1, "min": 0.874226713180542, "max": 0.874226713180542}}}
#
# #metrics {"StartTime": 1622620287.663373, "EndTime": 1622620287.6633887, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7966775894165039, "count": 1, "min": 0.7966775894165039, "max": 0.7966775894165039}}}
#
# #metrics {"StartTime": 1622620287.6634405, "EndTime": 1622620287.663458, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8014877033233643, "count": 1, "min": 0.8014877033233643, "max": 0.8014877033233643}}}
#
# #metrics {"StartTime": 1622620287.6635113, "EndTime": 1622620287.6635273, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.795371904373169, "count": 1, "min": 0.795371904373169, "max": 0.795371904373169}}}
#
# #metrics {"StartTime": 1622620287.6635773, "EndTime": 1622620287.6635933, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.798916072845459, "count": 1, "min": 0.798916072845459, "max": 0.798916072845459}}}
#
# #metrics {"StartTime": 1622620287.6636424, "EndTime": 1622620287.6636581, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8581383895874023, "count": 1, "min": 0.8581383895874023, "max": 0.8581383895874023}}}
#
# #metrics {"StartTime": 1622620287.663709, "EndTime": 1622620287.6637254, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9098024272918701, "count": 1, "min": 0.9098024272918701, "max": 0.9098024272918701}}}
#
# #metrics {"StartTime": 1622620287.6637778, "EndTime": 1622620287.6637945, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8854198932647706, "count": 1, "min": 0.8854198932647706, "max": 0.8854198932647706}}}
#
# #metrics {"StartTime": 1622620287.6638422, "EndTime": 1622620287.6638567, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.882696361541748, "count": 1, "min": 0.882696361541748, "max": 0.882696361541748}}}
#
# #metrics {"StartTime": 1622620287.6639025, "EndTime": 1622620287.6639185, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8169410800933838, "count": 1, "min": 0.8169410800933838, "max": 0.8169410800933838}}}
#
# #metrics {"StartTime": 1622620287.663969, "EndTime": 1622620287.6639855, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8294430732727051, "count": 1, "min": 0.8294430732727051, "max": 0.8294430732727051}}}
#
# #metrics {"StartTime": 1622620287.6640375, "EndTime": 1622620287.664054, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.806483097076416, "count": 1, "min": 0.806483097076416, "max": 0.806483097076416}}}
#
# #metrics {"StartTime": 1622620287.6641054, "EndTime": 1622620287.664122, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8643637561798095, "count": 1, "min": 0.8643637561798095, "max": 0.8643637561798095}}}
#
# #metrics {"StartTime": 1622620287.6641717, "EndTime": 1622620287.6641893, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8610915470123292, "count": 1, "min": 0.8610915470123292, "max": 0.8610915470123292}}}
#
# #metrics {"StartTime": 1622620287.66424, "EndTime": 1622620287.6642566, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9281379318237305, "count": 1, "min": 0.9281379318237305, "max": 0.9281379318237305}}}
#
# #metrics {"StartTime": 1622620287.66431, "EndTime": 1622620287.6643476, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9147527980804443, "count": 1, "min": 0.9147527980804443, "max": 0.9147527980804443}}}
#
# #metrics {"StartTime": 1622620287.664406, "EndTime": 1622620287.664424, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9040926551818848, "count": 1, "min": 0.9040926551818848, "max": 0.9040926551818848}}}
#
# #metrics {"StartTime": 1622620287.6644766, "EndTime": 1622620287.6644936, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9367700004577637, "count": 1, "min": 0.9367700004577637, "max": 0.9367700004577637}}}
#
# #metrics {"StartTime": 1622620287.6645443, "EndTime": 1622620287.66456, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9380142688751221, "count": 1, "min": 0.9380142688751221, "max": 0.9380142688751221}}}
#
# #metrics {"StartTime": 1622620287.6646059, "EndTime": 1622620287.6646194, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9642893409729004, "count": 1, "min": 0.9642893409729004, "max": 0.9642893409729004}}}
#
# #metrics {"StartTime": 1622620287.6646626, "EndTime": 1622620287.6646752, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9633904552459717, "count": 1, "min": 0.9633904552459717, "max": 0.9633904552459717}}}
#
# [06/02/2021 07:51:27 INFO 139899957315392] #quality_metric: host=algo-1, epoch=0, train absolute_loss_objective <loss>=0.8945285511016846
# [06/02/2021 07:51:27 INFO 139899957315392] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=absolute_loss_objective, value=0.7887770366668702
# [06/02/2021 07:51:27 INFO 139899957315392] Epoch 0: Loss improved. Updating best model
# [06/02/2021 07:51:27 INFO 139899957315392] Saving model for epoch: 0
# [06/02/2021 07:51:27 INFO 139899957315392] Saved checkpoint to "/tmp/tmpnzs6ykbd/mx-mod-0000.params"
# [06/02/2021 07:51:27 INFO 139899957315392] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1622620287.527392, "EndTime": 1622620287.6806493, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 57.0, "count": 1, "min": 57, "max": 57}, "Total Batches Seen": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 07:51:27 INFO 139899957315392] #throughput_metric: host=algo-1, train throughput=169.4979094845675 records/second
# [2021-06-02 07:51:27.855] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 174, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620287.8560197, "EndTime": 1622620287.8561058, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8557912635803223, "count": 1, "min": 0.8557912635803223, "max": 0.8557912635803223}}}
#
# #metrics {"StartTime": 1622620287.8571537, "EndTime": 1622620287.8571806, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8758560466766357, "count": 1, "min": 0.8758560466766357, "max": 0.8758560466766357}}}
#
# #metrics {"StartTime": 1622620287.857422, "EndTime": 1622620287.8574483, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8582218074798584, "count": 1, "min": 0.8582218074798584, "max": 0.8582218074798584}}}
#
# #metrics {"StartTime": 1622620287.857692, "EndTime": 1622620287.857717, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8748306465148926, "count": 1, "min": 0.8748306465148926, "max": 0.8748306465148926}}}
#
# #metrics {"StartTime": 1622620287.85797, "EndTime": 1622620287.8579955, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4750103092193603, "count": 1, "min": 0.4750103092193603, "max": 0.4750103092193603}}}
#
# #metrics {"StartTime": 1622620287.8582299, "EndTime": 1622620287.8582547, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4838706016540527, "count": 1, "min": 0.4838706016540527, "max": 0.4838706016540527}}}
#
# #metrics {"StartTime": 1622620287.8584893, "EndTime": 1622620287.8585136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.42718470573425293, "count": 1, "min": 0.42718470573425293, "max": 0.42718470573425293}}}
#
# #metrics {"StartTime": 1622620287.85877, "EndTime": 1622620287.8587942, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.568508243560791, "count": 1, "min": 0.568508243560791, "max": 0.568508243560791}}}
#
# #metrics {"StartTime": 1622620287.8590581, "EndTime": 1622620287.8590825, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9121278762817383, "count": 1, "min": 0.9121278762817383, "max": 0.9121278762817383}}}
#
# #metrics {"StartTime": 1622620287.8593469, "EndTime": 1622620287.8593717, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8436678123474121, "count": 1, "min": 0.8436678123474121, "max": 0.8436678123474121}}}
#
# #metrics {"StartTime": 1622620287.8596292, "EndTime": 1622620287.8596544, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8504190254211426, "count": 1, "min": 0.8504190254211426, "max": 0.8504190254211426}}}
#
# #metrics {"StartTime": 1622620287.8599234, "EndTime": 1622620287.8599486, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8354901599884034, "count": 1, "min": 0.8354901599884034, "max": 0.8354901599884034}}}
#
# #metrics {"StartTime": 1622620287.860255, "EndTime": 1622620287.8602786, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4834609603881836, "count": 1, "min": 0.4834609603881836, "max": 0.4834609603881836}}}
#
# #metrics {"StartTime": 1622620287.8605642, "EndTime": 1622620287.8605895, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7206231498718262, "count": 1, "min": 0.7206231498718262, "max": 0.7206231498718262}}}
#
# #metrics {"StartTime": 1622620287.860868, "EndTime": 1622620287.8608928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.48211127281188965, "count": 1, "min": 0.48211127281188965, "max": 0.48211127281188965}}}
#
# #metrics {"StartTime": 1622620287.8611612, "EndTime": 1622620287.8611844, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5502350234985351, "count": 1, "min": 0.5502350234985351, "max": 0.5502350234985351}}}
#
# #metrics {"StartTime": 1622620287.8612545, "EndTime": 1622620287.8612711, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.81951247215271, "count": 1, "min": 0.81951247215271, "max": 0.81951247215271}}}
#
# #metrics {"StartTime": 1622620287.861315, "EndTime": 1622620287.861359, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8710953235626221, "count": 1, "min": 0.8710953235626221, "max": 0.8710953235626221}}}
#
# #metrics {"StartTime": 1622620287.8614154, "EndTime": 1622620287.861432, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8467490863800049, "count": 1, "min": 0.8467490863800049, "max": 0.8467490863800049}}}
#
# #metrics {"StartTime": 1622620287.8614793, "EndTime": 1622620287.8614938, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8440298080444336, "count": 1, "min": 0.8440298080444336, "max": 0.8440298080444336}}}
#
# #metrics {"StartTime": 1622620287.8615391, "EndTime": 1622620287.8615534, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5938818550109863, "count": 1, "min": 0.5938818550109863, "max": 0.5938818550109863}}}
#
# #metrics {"StartTime": 1622620287.861599, "EndTime": 1622620287.8616133, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6028077983856202, "count": 1, "min": 0.6028077983856202, "max": 0.6028077983856202}}}
#
# #metrics {"StartTime": 1622620287.8616545, "EndTime": 1622620287.8616686, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5316579484939575, "count": 1, "min": 0.5316579484939575, "max": 0.5316579484939575}}}
#
# #metrics {"StartTime": 1622620287.861712, "EndTime": 1622620287.8617253, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.46307676792144775, "count": 1, "min": 0.46307676792144775, "max": 0.46307676792144775}}}
#
# #metrics {"StartTime": 1622620287.8617644, "EndTime": 1622620287.861776, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8644503784179688, "count": 1, "min": 0.8644503784179688, "max": 0.8644503784179688}}}
#
# #metrics {"StartTime": 1622620287.8618128, "EndTime": 1622620287.861824, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8905514430999756, "count": 1, "min": 0.8905514430999756, "max": 0.8905514430999756}}}
#
# #metrics {"StartTime": 1622620287.8618598, "EndTime": 1622620287.861871, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8799408435821533, "count": 1, "min": 0.8799408435821533, "max": 0.8799408435821533}}}
#
# #metrics {"StartTime": 1622620287.8619072, "EndTime": 1622620287.8619182, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8793697357177734, "count": 1, "min": 0.8793697357177734, "max": 0.8793697357177734}}}
#
# #metrics {"StartTime": 1622620287.8619545, "EndTime": 1622620287.8619657, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9024749660491943, "count": 1, "min": 0.9024749660491943, "max": 0.9024749660491943}}}
#
# #metrics {"StartTime": 1622620287.8620017, "EndTime": 1622620287.8620126, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9013331985473633, "count": 1, "min": 0.9013331985473633, "max": 0.9013331985473633}}}
#
# #metrics {"StartTime": 1622620287.8620489, "EndTime": 1622620287.8620596, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9040912055969238, "count": 1, "min": 0.9040912055969238, "max": 0.9040912055969238}}}
#
# #metrics {"StartTime": 1622620287.8620958, "EndTime": 1622620287.8621068, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9120360469818115, "count": 1, "min": 0.9120360469818115, "max": 0.9120360469818115}}}
#
# [06/02/2021 07:51:27 INFO 139899957315392] #quality_metric: host=algo-1, epoch=1, train absolute_loss_objective <loss>=0.8557912635803223
# [06/02/2021 07:51:27 INFO 139899957315392] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=absolute_loss_objective, value=0.42718470573425293
# [06/02/2021 07:51:27 INFO 139899957315392] Epoch 1: Loss improved. Updating best model
# [06/02/2021 07:51:27 INFO 139899957315392] Saving model for epoch: 1
# [06/02/2021 07:51:27 INFO 139899957315392] Saved checkpoint to "/tmp/tmpucdd6s22/mx-mod-0000.params"
# [06/02/2021 07:51:27 INFO 139899957315392] #progress_metric: host=algo-1, completed 40.0 % of epochs
# #metrics {"StartTime": 1622620287.6809306, "EndTime": 1622620287.8761566, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 83.0, "count": 1, "min": 83, "max": 83}, "Total Batches Seen": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 07:51:27 INFO 139899957315392] #throughput_metric: host=algo-1, train throughput=133.08978186105205 records/second
# [2021-06-02 07:51:28.059] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 175, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620288.0594103, "EndTime": 1622620288.0594852, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8242987442016602, "count": 1, "min": 0.8242987442016602, "max": 0.8242987442016602}}}
#
# #metrics {"StartTime": 1622620288.0595646, "EndTime": 1622620288.0595791, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8442750453948975, "count": 1, "min": 0.8442750453948975, "max": 0.8442750453948975}}}
#
# #metrics {"StartTime": 1622620288.0596204, "EndTime": 1622620288.0596318, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.826729326248169, "count": 1, "min": 0.826729326248169, "max": 0.826729326248169}}}
#
# #metrics {"StartTime": 1622620288.0596666, "EndTime": 1622620288.059677, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.843249683380127, "count": 1, "min": 0.843249683380127, "max": 0.843249683380127}}}
#
# #metrics {"StartTime": 1622620288.0597107, "EndTime": 1622620288.0597205, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20179739952087403, "count": 1, "min": 0.20179739952087403, "max": 0.20179739952087403}}}
#
# #metrics {"StartTime": 1622620288.0597541, "EndTime": 1622620288.059764, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20509454727172852, "count": 1, "min": 0.20509454727172852, "max": 0.20509454727172852}}}
#
# #metrics {"StartTime": 1622620288.059797, "EndTime": 1622620288.0598063, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.21177355766296388, "count": 1, "min": 0.21177355766296388, "max": 0.21177355766296388}}}
#
# #metrics {"StartTime": 1622620288.0598395, "EndTime": 1622620288.059849, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2453465962409973, "count": 1, "min": 0.2453465962409973, "max": 0.2453465962409973}}}
#
# #metrics {"StartTime": 1622620288.05989, "EndTime": 1622620288.059901, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8806359672546387, "count": 1, "min": 0.8806359672546387, "max": 0.8806359672546387}}}
#
# #metrics {"StartTime": 1622620288.0599356, "EndTime": 1622620288.059945, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8120884037017823, "count": 1, "min": 0.8120884037017823, "max": 0.8120884037017823}}}
#
# #metrics {"StartTime": 1622620288.05998, "EndTime": 1622620288.05999, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8189279842376709, "count": 1, "min": 0.8189279842376709, "max": 0.8189279842376709}}}
#
# #metrics {"StartTime": 1622620288.0600293, "EndTime": 1622620288.06004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8039108562469482, "count": 1, "min": 0.8039108562469482, "max": 0.8039108562469482}}}
#
# #metrics {"StartTime": 1622620288.0600803, "EndTime": 1622620288.0600915, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20357991695404054, "count": 1, "min": 0.20357991695404054, "max": 0.20357991695404054}}}
#
# #metrics {"StartTime": 1622620288.0601265, "EndTime": 1622620288.0601358, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3027788162231445, "count": 1, "min": 0.3027788162231445, "max": 0.3027788162231445}}}
#
# #metrics {"StartTime": 1622620288.0601754, "EndTime": 1622620288.060186, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20329114198684692, "count": 1, "min": 0.20329114198684692, "max": 0.20329114198684692}}}
#
# #metrics {"StartTime": 1622620288.0602207, "EndTime": 1622620288.0602305, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2087265992164612, "count": 1, "min": 0.2087265992164612, "max": 0.2087265992164612}}}
#
# #metrics {"StartTime": 1622620288.0602634, "EndTime": 1622620288.0602732, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7882349681854248, "count": 1, "min": 0.7882349681854248, "max": 0.7882349681854248}}}
#
# #metrics {"StartTime": 1622620288.0603058, "EndTime": 1622620288.0603154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8396374797821045, "count": 1, "min": 0.8396374797821045, "max": 0.8396374797821045}}}
#
# #metrics {"StartTime": 1622620288.0603812, "EndTime": 1622620288.0603948, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8154204654693603, "count": 1, "min": 0.8154204654693603, "max": 0.8154204654693603}}}
#
# #metrics {"StartTime": 1622620288.060431, "EndTime": 1622620288.0604408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8126184844970703, "count": 1, "min": 0.8126184844970703, "max": 0.8126184844970703}}}
#
# #metrics {"StartTime": 1622620288.0604746, "EndTime": 1622620288.0604842, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2620376539230347, "count": 1, "min": 0.2620376539230347, "max": 0.2620376539230347}}}
#
# #metrics {"StartTime": 1622620288.060517, "EndTime": 1622620288.0605266, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2655638360977173, "count": 1, "min": 0.2655638360977173, "max": 0.2655638360977173}}}
#
# #metrics {"StartTime": 1622620288.0605593, "EndTime": 1622620288.060569, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2665154600143433, "count": 1, "min": 0.2665154600143433, "max": 0.2665154600143433}}}
#
# #metrics {"StartTime": 1622620288.0606022, "EndTime": 1622620288.0606115, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33890653610229493, "count": 1, "min": 0.33890653610229493, "max": 0.33890653610229493}}}
#
# #metrics {"StartTime": 1622620288.0606449, "EndTime": 1622620288.0606546, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.871562910079956, "count": 1, "min": 0.871562910079956, "max": 0.871562910079956}}}
#
# #metrics {"StartTime": 1622620288.060687, "EndTime": 1622620288.0606966, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8663798809051514, "count": 1, "min": 0.8663798809051514, "max": 0.8663798809051514}}}
#
# #metrics {"StartTime": 1622620288.0607293, "EndTime": 1622620288.0607388, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8654977321624756, "count": 1, "min": 0.8654977321624756, "max": 0.8654977321624756}}}
#
# #metrics {"StartTime": 1622620288.0607798, "EndTime": 1622620288.0607936, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8751721954345704, "count": 1, "min": 0.8751721954345704, "max": 0.8751721954345704}}}
#
# #metrics {"StartTime": 1622620288.0608451, "EndTime": 1622620288.0608616, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8977360439300537, "count": 1, "min": 0.8977360439300537, "max": 0.8977360439300537}}}
#
# #metrics {"StartTime": 1622620288.060906, "EndTime": 1622620288.060922, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8992594337463379, "count": 1, "min": 0.8992594337463379, "max": 0.8992594337463379}}}
#
# #metrics {"StartTime": 1622620288.06097, "EndTime": 1622620288.0609858, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8880680274963378, "count": 1, "min": 0.8880680274963378, "max": 0.8880680274963378}}}
#
# #metrics {"StartTime": 1622620288.0610342, "EndTime": 1622620288.0610504, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.876504545211792, "count": 1, "min": 0.876504545211792, "max": 0.876504545211792}}}
#
# [06/02/2021 07:51:28 INFO 139899957315392] #quality_metric: host=algo-1, epoch=2, train absolute_loss_objective <loss>=0.8242987442016602
# [06/02/2021 07:51:28 INFO 139899957315392] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=absolute_loss_objective, value=0.20179739952087403
# [06/02/2021 07:51:28 INFO 139899957315392] Epoch 2: Loss improved. Updating best model
# [06/02/2021 07:51:28 INFO 139899957315392] Saving model for epoch: 2
# [06/02/2021 07:51:28 INFO 139899957315392] Saved checkpoint to "/tmp/tmpktxonwma/mx-mod-0000.params"
# [06/02/2021 07:51:28 INFO 139899957315392] #progress_metric: host=algo-1, completed 60.0 % of epochs
# #metrics {"StartTime": 1622620287.87647, "EndTime": 1622620288.0706487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 109.0, "count": 1, "min": 109, "max": 109}, "Total Batches Seen": {"sum": 25.0, "count": 1, "min": 25, "max": 25}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 07:51:28 INFO 139899957315392] #throughput_metric: host=algo-1, train throughput=133.80158448738507 records/second
# [2021-06-02 07:51:28.193] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 122, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620288.1940193, "EndTime": 1622620288.194094, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7938915824890137, "count": 1, "min": 0.7938915824890137, "max": 0.7938915824890137}}}
#
# #metrics {"StartTime": 1622620288.1944332, "EndTime": 1622620288.1944554, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8135607719421387, "count": 1, "min": 0.8135607719421387, "max": 0.8135607719421387}}}
#
# #metrics {"StartTime": 1622620288.1946063, "EndTime": 1622620288.1946456, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7963221836090087, "count": 1, "min": 0.7963221836090087, "max": 0.7963221836090087}}}
#
# #metrics {"StartTime": 1622620288.194827, "EndTime": 1622620288.1948452, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8125353431701661, "count": 1, "min": 0.8125353431701661, "max": 0.8125353431701661}}}
#
# #metrics {"StartTime": 1622620288.1950743, "EndTime": 1622620288.1951518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.300389199256897, "count": 1, "min": 0.300389199256897, "max": 0.300389199256897}}}
#
# #metrics {"StartTime": 1622620288.1952062, "EndTime": 1622620288.1952589, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2947694158554077, "count": 1, "min": 0.2947694158554077, "max": 0.2947694158554077}}}
#
# #metrics {"StartTime": 1622620288.195433, "EndTime": 1622620288.1954548, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.34739300966262815, "count": 1, "min": 0.34739300966262815, "max": 0.34739300966262815}}}
#
# #metrics {"StartTime": 1622620288.1954951, "EndTime": 1622620288.1955109, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.31880349159240723, "count": 1, "min": 0.31880349159240723, "max": 0.31880349159240723}}}
#
# #metrics {"StartTime": 1622620288.1955643, "EndTime": 1622620288.195581, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.850230712890625, "count": 1, "min": 0.850230712890625, "max": 0.850230712890625}}}
#
# #metrics {"StartTime": 1622620288.1956327, "EndTime": 1622620288.19565, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7813770198822021, "count": 1, "min": 0.7813770198822021, "max": 0.7813770198822021}}}
#
# #metrics {"StartTime": 1622620288.195702, "EndTime": 1622620288.195719, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7885236358642578, "count": 1, "min": 0.7885236358642578, "max": 0.7885236358642578}}}
#
# #metrics {"StartTime": 1622620288.1957707, "EndTime": 1622620288.1957872, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7731996059417725, "count": 1, "min": 0.7731996059417725, "max": 0.7731996059417725}}}
#
# #metrics {"StartTime": 1622620288.1958368, "EndTime": 1622620288.1958528, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.28878944873809814, "count": 1, "min": 0.28878944873809814, "max": 0.28878944873809814}}}
#
# #metrics {"StartTime": 1622620288.1959035, "EndTime": 1622620288.1959202, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.32330681800842287, "count": 1, "min": 0.32330681800842287, "max": 0.32330681800842287}}}
#
# #metrics {"StartTime": 1622620288.1959739, "EndTime": 1622620288.1959913, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2900800657272339, "count": 1, "min": 0.2900800657272339, "max": 0.2900800657272339}}}
#
# ...
# [06/02/2021 07:51:28 INFO 139899957315392] #progress_metric: host=algo-1, completed 80.0 % of epochs
# #metrics {"StartTime": 1622620288.0709343, "EndTime": 1622620288.2096064, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 135.0, "count": 1, "min": 135, "max": 135}, "Total Batches Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 07:51:28 INFO 139899957315392] #throughput_metric: host=algo-1, train throughput=187.29781292186357 records/second
# [2021-06-02 07:51:28.327] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 12, "duration": 117, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620288.3271651, "EndTime": 1622620288.3272157, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7723214626312256, "count": 1, "min": 0.7723214626312256, "max": 0.7723214626312256}}}
#
# #metrics {"StartTime": 1622620288.3272734, "EndTime": 1622620288.3272858, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7900911426544189, "count": 1, "min": 0.7900911426544189, "max": 0.7900911426544189}}}
#
# #metrics {"StartTime": 1622620288.3273156, "EndTime": 1622620288.327324, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7745308399200439, "count": 1, "min": 0.7745308399200439, "max": 0.7745308399200439}}}
#
# #metrics {"StartTime": 1622620288.3273692, "EndTime": 1622620288.327385, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7891590690612793, "count": 1, "min": 0.7891590690612793, "max": 0.7891590690612793}}}
#
# #metrics {"StartTime": 1622620288.3274374, "EndTime": 1622620288.327454, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2534684824943543, "count": 1, "min": 0.2534684824943543, "max": 0.2534684824943543}}}
#
# #metrics {"StartTime": 1622620288.32751, "EndTime": 1622620288.3275268, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2497752094268799, "count": 1, "min": 0.2497752094268799, "max": 0.2497752094268799}}}
#
# #metrics {"StartTime": 1622620288.3275633, "EndTime": 1622620288.3275726, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3031576108932495, "count": 1, "min": 0.3031576108932495, "max": 0.3031576108932495}}}
#
# #metrics {"StartTime": 1622620288.3275974, "EndTime": 1622620288.327605, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.22437820196151734, "count": 1, "min": 0.22437820196151734, "max": 0.22437820196151734}}}
#
# #metrics {"StartTime": 1622620288.3276286, "EndTime": 1622620288.3276358, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.825195255279541, "count": 1, "min": 0.825195255279541, "max": 0.825195255279541}}}
#
# #metrics {"StartTime": 1622620288.3276587, "EndTime": 1622620288.3276658, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7608409309387207, "count": 1, "min": 0.7608409309387207, "max": 0.7608409309387207}}}
#
# #metrics {"StartTime": 1622620288.327689, "EndTime": 1622620288.327696, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7674464607238769, "count": 1, "min": 0.7674464607238769, "max": 0.7674464607238769}}}
#
# #metrics {"StartTime": 1622620288.3277194, "EndTime": 1622620288.327732, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7534078311920166, "count": 1, "min": 0.7534078311920166, "max": 0.7534078311920166}}}
#
# #metrics {"StartTime": 1622620288.3277795, "EndTime": 1622620288.3277955, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.24247640371322632, "count": 1, "min": 0.24247640371322632, "max": 0.24247640371322632}}}
#
# #metrics {"StartTime": 1622620288.327844, "EndTime": 1622620288.3278584, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.29072519063949587, "count": 1, "min": 0.29072519063949587, "max": 0.29072519063949587}}}
#
# #metrics {"StartTime": 1622620288.327905, "EndTime": 1622620288.3279204, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.24336956262588502, "count": 1, "min": 0.24336956262588502, "max": 0.24336956262588502}}}
#
# #metrics {"StartTime": 1622620288.3279688, "EndTime": 1622620288.3279846, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.21867279291152955, "count": 1, "min": 0.21867279291152955, "max": 0.21867279291152955}}}
#
# #metrics {"StartTime": 1622620288.3280334, "EndTime": 1622620288.3280487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7396121978759765, "count": 1, "min": 0.7396121978759765, "max": 0.7396121978759765}}}
#
# #metrics {"StartTime": 1622620288.3280997, "EndTime": 1622620288.3281145, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7865690803527832, "count": 1, "min": 0.7865690803527832, "max": 0.7865690803527832}}}
#
# #metrics {"StartTime": 1622620288.3281639, "EndTime": 1622620288.3281803, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7650337886810302, "count": 1, "min": 0.7650337886810302, "max": 0.7650337886810302}}}
#
# #metrics {"StartTime": 1622620288.3282328, "EndTime": 1622620288.3282485, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7621239376068115, "count": 1, "min": 0.7621239376068115, "max": 0.7621239376068115}}}
#
# #metrics {"StartTime": 1622620288.3282971, "EndTime": 1622620288.3283134, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4365283679962158, "count": 1, "min": 0.4365283679962158, "max": 0.4365283679962158}}}
#
# #metrics {"StartTime": 1622620288.3283973, "EndTime": 1622620288.3284154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4343521785736084, "count": 1, "min": 0.4343521785736084, "max": 0.4343521785736084}}}
#
# #metrics {"StartTime": 1622620288.3284636, "EndTime": 1622620288.3284743, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3786530637741089, "count": 1, "min": 0.3786530637741089, "max": 0.3786530637741089}}}
#
# #metrics {"StartTime": 1622620288.3285112, "EndTime": 1622620288.3285272, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3593438577651977, "count": 1, "min": 0.3593438577651977, "max": 0.3593438577651977}}}
#
# #metrics {"StartTime": 1622620288.328577, "EndTime": 1622620288.3285918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.870873441696167, "count": 1, "min": 0.870873441696167, "max": 0.870873441696167}}}
#
# #metrics {"StartTime": 1622620288.3286412, "EndTime": 1622620288.328659, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8533285999298096, "count": 1, "min": 0.8533285999298096, "max": 0.8533285999298096}}}
#
# #metrics {"StartTime": 1622620288.3287091, "EndTime": 1622620288.3287256, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8628853988647461, "count": 1, "min": 0.8628853988647461, "max": 0.8628853988647461}}}
#
# #metrics {"StartTime": 1622620288.3287764, "EndTime": 1622620288.328792, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8580431938171387, "count": 1, "min": 0.8580431938171387, "max": 0.8580431938171387}}}
#
# #metrics {"StartTime": 1622620288.328843, "EndTime": 1622620288.3288593, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9994428443908692, "count": 1, "min": 0.9994428443908692, "max": 0.9994428443908692}}}
#
# #metrics {"StartTime": 1622620288.3289108, "EndTime": 1622620288.328927, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0013238525390624, "count": 1, "min": 1.0013238525390624, "max": 1.0013238525390624}}}
#
# #metrics {"StartTime": 1622620288.3289778, "EndTime": 1622620288.3289895, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8635519218444824, "count": 1, "min": 0.8635519218444824, "max": 0.8635519218444824}}}
#
# #metrics {"StartTime": 1622620288.329039, "EndTime": 1622620288.329056, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8558250045776368, "count": 1, "min": 0.8558250045776368, "max": 0.8558250045776368}}}
#
# [06/02/2021 07:51:28 INFO 139899957315392] #quality_metric: host=algo-1, epoch=4, train absolute_loss_objective <loss>=0.7723214626312256
# [06/02/2021 07:51:28 INFO 139899957315392] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=absolute_loss_objective, value=0.21867279291152955
# [06/02/2021 07:51:28 INFO 139899957315392] Saving model for epoch: 4
# [06/02/2021 07:51:28 INFO 139899957315392] Saved checkpoint to "/tmp/tmp5zmqqnky/mx-mod-0000.params"
# [06/02/2021 07:51:28 INFO 139899957315392] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1622620288.2099192, "EndTime": 1622620288.3378143, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 161.0, "count": 1, "min": 161, "max": 161}, "Total Batches Seen": {"sum": 37.0, "count": 1, "min": 37, "max": 37}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 07:51:28 INFO 139899957315392] #throughput_metric: host=algo-1, train throughput=203.14653492643635 records/second
# [06/02/2021 07:51:28 WARNING 139899957315392] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/02/2021 07:51:28 WARNING 139899957315392] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-06-02 07:51:28.338] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 14, "duration": 0, "num_examples": 1, "num_bytes": 240}
# [2021-06-02 07:51:28.353] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 16, "duration": 11, "num_examples": 6, "num_bytes": 1248}
# [06/02/2021 07:51:28 INFO 139899957315392] #train_score (algo-1) : ('absolute_loss_objective', 8610.715745192309)
# [06/02/2021 07:51:28 INFO 139899957315392] #train_score (algo-1) : ('mse', 103096993.23076923)
# [06/02/2021 07:51:28 INFO 139899957315392] #train_score (algo-1) : ('absolute_loss', 8610.715745192309)
# [06/02/2021 07:51:28 INFO 139899957315392] #quality_metric: host=algo-1, train absolute_loss_objective <loss>=8610.715745192309
# [06/02/2021 07:51:28 INFO 139899957315392] #quality_metric: host=algo-1, train mse <loss>=103096993.23076923
# [06/02/2021 07:51:28 INFO 139899957315392] #quality_metric: host=algo-1, train absolute_loss <loss>=8610.715745192309
# [06/02/2021 07:51:28 INFO 139899957315392] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 1, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [06/02/2021 07:51:28 INFO 139899957315392] Saved checkpoint to "/tmp/tmpv1rsgsi2/mx-mod-0000.params"
# [06/02/2021 07:51:28 INFO 139899957315392] Test data is not provided.
# #metrics {"StartTime": 1622620287.3257546, "EndTime": 1622620288.3609455, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 200.35219192504883, "count": 1, "min": 200.35219192504883, "max": 200.35219192504883}, "epochs": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "check_early_stopping.time": {"sum": 4.764556884765625, "count": 5, "min": 0.1766681671142578, "max": 1.2960433959960938}, "update.time": {"sum": 784.2586040496826, "count": 5, "min": 125.08964538574219, "max": 191.41626358032227}, "finalize.time": {"sum": 16.138076782226562, "count": 1, "min": 16.138076782226562, "max": 16.138076782226562}, "setuptime": {"sum": 23.406505584716797, "count": 1, "min": 23.406505584716797, "max": 23.406505584716797}, "totaltime": {"sum": 1249.284029006958, "count": 1, "min": 1249.284029006958, "max": 1249.284029006958}}}
#
#
# 2021-06-02 07:51:48 Uploading - Uploading generated training model
# 2021-06-02 07:51:48 Completed - Training job completed
# Training seconds: 72
# Billable seconds: 72

# %% [markdown]
# MINI CHALLENGE
# - Try to train the model with more epochs and additional number of models
# - Can you try to reduce the cost of billable seconds?

# %%
# We have pass in the container, the type of instance that we would like to use for training 
# output path and sagemaker session into the Estimator. 
# We can also specify how many instances we would like to use for training
# sagemaker_session = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count = 1, 
                                       train_instance_type = 'ml.c4.xlarge',
                                       output_path = output_location,
                                       sagemaker_session = sagemaker_session)


# We can tune parameters like the number of features that we are passing in, type of predictor like 'regressor' or 'classifier', mini batch size, epochs
# Train 32 different versions of the model and will get the best out of them (built-in parameters optimization!)

linear.set_hyperparameters(feature_dim = 1,
                           predictor_type = 'regressor',
                           mini_batch_size = 5,
                           epochs = 50,
                           num_models = 32,
                           loss = 'absolute_loss')

# Now we are ready to pass in the training data from S3 to train the linear learner model

linear.fit({'train': s3_train_data})

# Let's see the progress using cloudwatch logs
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-06-02 07:53:42 Starting - Starting the training job...
# 2021-06-02 07:54:05 Starting - Launching requested ML instancesProfilerReport-1622620422: InProgress
# ......
# 2021-06-02 07:55:06 Starting - Preparing the instances for training......
# 2021-06-02 07:56:12 Downloading - Downloading input data...
# 2021-06-02 07:56:37 Training - Downloading the training image...
# 2021-06-02 07:57:08 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [06/02/2021 07:57:03 INFO 140537759278912] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [06/02/2021 07:57:03 INFO 140537759278912] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'loss': 'absolute_loss', 'feature_dim': '1', 'num_models': '32', 'predictor_type': 'regressor', 'epochs': '50', 'mini_batch_size': '5'}
# [06/02/2021 07:57:03 INFO 140537759278912] Final configuration: {'mini_batch_size': '5', 'epochs': '50', 'feature_dim': '1', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '32', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'absolute_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [06/02/2021 07:57:03 WARNING 140537759278912] Loggers have already been setup.
# Process 1 is a worker.
# [06/02/2021 07:57:03 INFO 140537759278912] Using default worker.
# [06/02/2021 07:57:03 INFO 140537759278912] Checkpoint loading and saving are disabled.
# [2021-06-02 07:57:03.717] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 15, "num_examples": 1, "num_bytes": 240}
# [06/02/2021 07:57:03 INFO 140537759278912] Create Store: local
# [2021-06-02 07:57:03.777] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 59, "num_examples": 6, "num_bytes": 1248}
# [06/02/2021 07:57:03 INFO 140537759278912] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fd11e74a810>
# [06/02/2021 07:57:03 INFO 140537759278912] Scaling model computed with parameters:
#  {'stdev_label':
# [31895.934]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [3.4896421]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [79380.4]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [5.7799997]
# <NDArray 1 @cpu(0)>}
# [06/02/2021 07:57:03 INFO 140537759278912] nvidia-smi: took 0.031 seconds to run.
# [06/02/2021 07:57:03 INFO 140537759278912] nvidia-smi identified 0 GPUs.
# [06/02/2021 07:57:03 INFO 140537759278912] Number of GPUs being used: 0
# #metrics {"StartTime": 1622620623.896456, "EndTime": 1622620623.8964915, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Total Batches Seen": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-06-02 07:57:04.052] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 155, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620624.0523083, "EndTime": 1622620624.0524104, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8945285511016846, "count": 1, "min": 0.8945285511016846, "max": 0.8945285511016846}}}
#
# #metrics {"StartTime": 1622620624.0525084, "EndTime": 1622620624.0525298, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9145934009552001, "count": 1, "min": 0.9145934009552001, "max": 0.9145934009552001}}}
#
# #metrics {"StartTime": 1622620624.052589, "EndTime": 1622620624.0526068, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8969591331481933, "count": 1, "min": 0.8969591331481933, "max": 0.8969591331481933}}}
#
# #metrics {"StartTime": 1622620624.0526645, "EndTime": 1622620624.0526826, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9135679912567138, "count": 1, "min": 0.9135679912567138, "max": 0.9135679912567138}}}
#
# #metrics {"StartTime": 1622620624.052737, "EndTime": 1622620624.0527537, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7887770366668702, "count": 1, "min": 0.7887770366668702, "max": 0.7887770366668702}}}
#
# #metrics {"StartTime": 1622620624.0528064, "EndTime": 1622620624.052823, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7973329544067382, "count": 1, "min": 0.7973329544067382, "max": 0.7973329544067382}}}
#
# #metrics {"StartTime": 1622620624.0528786, "EndTime": 1622620624.0528967, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8596661376953125, "count": 1, "min": 0.8596661376953125, "max": 0.8596661376953125}}}
#
# #metrics {"StartTime": 1622620624.0529497, "EndTime": 1622620624.0529656, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8193386936187744, "count": 1, "min": 0.8193386936187744, "max": 0.8193386936187744}}}
#
# #metrics {"StartTime": 1622620624.0530176, "EndTime": 1622620624.0530343, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9508654689788818, "count": 1, "min": 0.9508654689788818, "max": 0.9508654689788818}}}
#
# #metrics {"StartTime": 1622620624.0530849, "EndTime": 1622620624.0531015, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8824044704437256, "count": 1, "min": 0.8824044704437256, "max": 0.8824044704437256}}}
#
# #metrics {"StartTime": 1622620624.0531523, "EndTime": 1622620624.053169, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8891557693481446, "count": 1, "min": 0.8891557693481446, "max": 0.8891557693481446}}}
#
# #metrics {"StartTime": 1622620624.05322, "EndTime": 1622620624.053236, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.874226713180542, "count": 1, "min": 0.874226713180542, "max": 0.874226713180542}}}
#
# #metrics {"StartTime": 1622620624.0532887, "EndTime": 1622620624.0533054, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7966775894165039, "count": 1, "min": 0.7966775894165039, "max": 0.7966775894165039}}}
#
# #metrics {"StartTime": 1622620624.0533566, "EndTime": 1622620624.053373, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8014877033233643, "count": 1, "min": 0.8014877033233643, "max": 0.8014877033233643}}}
#
# #metrics {"StartTime": 1622620624.0534296, "EndTime": 1622620624.053445, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.795371904373169, "count": 1, "min": 0.795371904373169, "max": 0.795371904373169}}}
#
# #metrics {"StartTime": 1622620624.0535, "EndTime": 1622620624.0535157, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.798916072845459, "count": 1, "min": 0.798916072845459, "max": 0.798916072845459}}}
#
# #metrics {"StartTime": 1622620624.05357, "EndTime": 1622620624.0535867, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8581383895874023, "count": 1, "min": 0.8581383895874023, "max": 0.8581383895874023}}}
#
# #metrics {"StartTime": 1622620624.0536385, "EndTime": 1622620624.0536535, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9098024272918701, "count": 1, "min": 0.9098024272918701, "max": 0.9098024272918701}}}
#
# #metrics {"StartTime": 1622620624.0537043, "EndTime": 1622620624.05372, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8854198932647706, "count": 1, "min": 0.8854198932647706, "max": 0.8854198932647706}}}
#
# #metrics {"StartTime": 1622620624.0537739, "EndTime": 1622620624.05379, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.882696361541748, "count": 1, "min": 0.882696361541748, "max": 0.882696361541748}}}
#
# #metrics {"StartTime": 1622620624.0538425, "EndTime": 1622620624.053858, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8169410800933838, "count": 1, "min": 0.8169410800933838, "max": 0.8169410800933838}}}
#
# #metrics {"StartTime": 1622620624.0539088, "EndTime": 1622620624.0539236, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8294430732727051, "count": 1, "min": 0.8294430732727051, "max": 0.8294430732727051}}}
#
# #metrics {"StartTime": 1622620624.053975, "EndTime": 1622620624.0539908, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.806483097076416, "count": 1, "min": 0.806483097076416, "max": 0.806483097076416}}}
#
# #metrics {"StartTime": 1622620624.054043, "EndTime": 1622620624.0540595, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8643637561798095, "count": 1, "min": 0.8643637561798095, "max": 0.8643637561798095}}}
#
# #metrics {"StartTime": 1622620624.05411, "EndTime": 1622620624.0541263, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8610915470123292, "count": 1, "min": 0.8610915470123292, "max": 0.8610915470123292}}}
#
# #metrics {"StartTime": 1622620624.0541773, "EndTime": 1622620624.0541923, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9281379318237305, "count": 1, "min": 0.9281379318237305, "max": 0.9281379318237305}}}
#
# #metrics {"StartTime": 1622620624.0542772, "EndTime": 1622620624.0542953, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9147527980804443, "count": 1, "min": 0.9147527980804443, "max": 0.9147527980804443}}}
#
# #metrics {"StartTime": 1622620624.0543485, "EndTime": 1622620624.0543652, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9040926551818848, "count": 1, "min": 0.9040926551818848, "max": 0.9040926551818848}}}
#
# #metrics {"StartTime": 1622620624.054452, "EndTime": 1622620624.0544703, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9367700004577637, "count": 1, "min": 0.9367700004577637, "max": 0.9367700004577637}}}
#
# #metrics {"StartTime": 1622620624.0545225, "EndTime": 1622620624.0545392, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9380142688751221, "count": 1, "min": 0.9380142688751221, "max": 0.9380142688751221}}}
#
# #metrics {"StartTime": 1622620624.0545914, "EndTime": 1622620624.0546076, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9642893409729004, "count": 1, "min": 0.9642893409729004, "max": 0.9642893409729004}}}
#
# #metrics {"StartTime": 1622620624.0546565, "EndTime": 1622620624.0546727, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9633904552459717, "count": 1, "min": 0.9633904552459717, "max": 0.9633904552459717}}}
#
# [06/02/2021 07:57:04 INFO 140537759278912] #quality_metric: host=algo-1, epoch=0, train absolute_loss_objective <loss>=0.8945285511016846
# [06/02/2021 07:57:04 INFO 140537759278912] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=absolute_loss_objective, value=0.7887770366668702
# [06/02/2021 07:57:04 INFO 140537759278912] Epoch 0: Loss improved. Updating best model
# [06/02/2021 07:57:04 INFO 140537759278912] Saving model for epoch: 0
# [06/02/2021 07:57:04 INFO 140537759278912] Saved checkpoint to "/tmp/tmpecnxbos3/mx-mod-0000.params"
# [06/02/2021 07:57:04 INFO 140537759278912] #progress_metric: host=algo-1, completed 2.0 % of epochs
# #metrics {"StartTime": 1622620623.8968372, "EndTime": 1622620624.071018, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 57.0, "count": 1, "min": 57, "max": 57}, "Total Batches Seen": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 07:57:04 INFO 140537759278912] #throughput_metric: host=algo-1, train throughput=149.13815107478794 records/second
# [2021-06-02 07:57:04.259] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 188, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620624.2598982, "EndTime": 1622620624.2600079, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8557912635803223, "count": 1, "min": 0.8557912635803223, "max": 0.8557912635803223}}}
#
# #metrics {"StartTime": 1622620624.2600863, "EndTime": 1622620624.260105, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8758560466766357, "count": 1, "min": 0.8758560466766357, "max": 0.8758560466766357}}}
#
# #metrics {"StartTime": 1622620624.2601862, "EndTime": 1622620624.2602026, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8582218074798584, "count": 1, "min": 0.8582218074798584, "max": 0.8582218074798584}}}
#
# #metrics {"StartTime": 1622620624.260258, "EndTime": 1622620624.260302, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8748306465148926, "count": 1, "min": 0.8748306465148926, "max": 0.8748306465148926}}}
#
# #metrics {"StartTime": 1622620624.2603598, "EndTime": 1622620624.260377, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4750103092193603, "count": 1, "min": 0.4750103092193603, "max": 0.4750103092193603}}}
#
# #metrics {"StartTime": 1622620624.260458, "EndTime": 1622620624.2604783, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4838706016540527, "count": 1, "min": 0.4838706016540527, "max": 0.4838706016540527}}}
#
# #metrics {"StartTime": 1622620624.2605317, "EndTime": 1622620624.260575, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.42718470573425293, "count": 1, "min": 0.42718470573425293, "max": 0.42718470573425293}}}
#
# #metrics {"StartTime": 1622620624.2606373, "EndTime": 1622620624.2606554, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.568508243560791, "count": 1, "min": 0.568508243560791, "max": 0.568508243560791}}}
#
# #metrics {"StartTime": 1622620624.2607462, "EndTime": 1622620624.2607667, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9121278762817383, "count": 1, "min": 0.9121278762817383, "max": 0.9121278762817383}}}
#
# #metrics {"StartTime": 1622620624.2608216, "EndTime": 1622620624.260838, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8436678123474121, "count": 1, "min": 0.8436678123474121, "max": 0.8436678123474121}}}
#
# #metrics {"StartTime": 1622620624.2609272, "EndTime": 1622620624.2609465, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8504190254211426, "count": 1, "min": 0.8504190254211426, "max": 0.8504190254211426}}}
#
# #metrics {"StartTime": 1622620624.2609997, "EndTime": 1622620624.261016, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8354901599884034, "count": 1, "min": 0.8354901599884034, "max": 0.8354901599884034}}}
#
# #metrics {"StartTime": 1622620624.2610607, "EndTime": 1622620624.2610724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4834609603881836, "count": 1, "min": 0.4834609603881836, "max": 0.4834609603881836}}}
#
# #metrics {"StartTime": 1622620624.261114, "EndTime": 1622620624.261127, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7206231498718262, "count": 1, "min": 0.7206231498718262, "max": 0.7206231498718262}}}
#
# #metrics {"StartTime": 1622620624.261169, "EndTime": 1622620624.2611806, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.48211127281188965, "count": 1, "min": 0.48211127281188965, "max": 0.48211127281188965}}}
#
# #metrics {"StartTime": 1622620624.2612214, "EndTime": 1622620624.2612329, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5502350234985351, "count": 1, "min": 0.5502350234985351, "max": 0.5502350234985351}}}
#
# #metrics {"StartTime": 1622620624.2612734, "EndTime": 1622620624.2612846, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.81951247215271, "count": 1, "min": 0.81951247215271, "max": 0.81951247215271}}}
#
# #metrics {"StartTime": 1622620624.2613246, "EndTime": 1622620624.2613363, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8710953235626221, "count": 1, "min": 0.8710953235626221, "max": 0.8710953235626221}}}
#
# #metrics {"StartTime": 1622620624.2613847, "EndTime": 1622620624.2613993, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8467490863800049, "count": 1, "min": 0.8467490863800049, "max": 0.8467490863800049}}}
#
# #metrics {"StartTime": 1622620624.2614515, "EndTime": 1622620624.261467, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8440298080444336, "count": 1, "min": 0.8440298080444336, "max": 0.8440298080444336}}}
#
# #metrics {"StartTime": 1622620624.2615144, "EndTime": 1622620624.2615304, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5938818550109863, "count": 1, "min": 0.5938818550109863, "max": 0.5938818550109863}}}
#
# #metrics {"StartTime": 1622620624.2615824, "EndTime": 1622620624.261598, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6028077983856202, "count": 1, "min": 0.6028077983856202, "max": 0.6028077983856202}}}
#
# #metrics {"StartTime": 1622620624.2616494, "EndTime": 1622620624.2616656, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5316579484939575, "count": 1, "min": 0.5316579484939575, "max": 0.5316579484939575}}}
#
# #metrics {"StartTime": 1622620624.261716, "EndTime": 1622620624.2617316, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.46307676792144775, "count": 1, "min": 0.46307676792144775, "max": 0.46307676792144775}}}
#
# #metrics {"StartTime": 1622620624.2617812, "EndTime": 1622620624.2617972, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8644503784179688, "count": 1, "min": 0.8644503784179688, "max": 0.8644503784179688}}}
#
# #metrics {"StartTime": 1622620624.2618473, "EndTime": 1622620624.2618637, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8905514430999756, "count": 1, "min": 0.8905514430999756, "max": 0.8905514430999756}}}
#
# #metrics {"StartTime": 1622620624.2619104, "EndTime": 1622620624.2619233, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8799408435821533, "count": 1, "min": 0.8799408435821533, "max": 0.8799408435821533}}}
#
# #metrics {"StartTime": 1622620624.2619648, "EndTime": 1622620624.2619767, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8793697357177734, "count": 1, "min": 0.8793697357177734, "max": 0.8793697357177734}}}
#
# #metrics {"StartTime": 1622620624.2620194, "EndTime": 1622620624.262032, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9024749660491943, "count": 1, "min": 0.9024749660491943, "max": 0.9024749660491943}}}
#
# #metrics {"StartTime": 1622620624.2620726, "EndTime": 1622620624.2620842, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9013331985473633, "count": 1, "min": 0.9013331985473633, "max": 0.9013331985473633}}}
#
# #metrics {"StartTime": 1622620624.2621238, "EndTime": 1622620624.2621353, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9040912055969238, "count": 1, "min": 0.9040912055969238, "max": 0.9040912055969238}}}
#
# #metrics {"StartTime": 1622620624.2621784, "EndTime": 1622620624.2621906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9120360469818115, "count": 1, "min": 0.9120360469818115, "max": 0.9120360469818115}}}
#
# [06/02/2021 07:57:04 INFO 140537759278912] #quality_metric: host=algo-1, epoch=1, train absolute_loss_objective <loss>=0.8557912635803223
# [06/02/2021 07:57:04 INFO 140537759278912] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=absolute_loss_objective, value=0.42718470573425293
# [06/02/2021 07:57:04 INFO 140537759278912] Epoch 1: Loss improved. Updating best model
# [06/02/2021 07:57:04 INFO 140537759278912] Saving model for epoch: 1
# [06/02/2021 07:57:04 INFO 140537759278912] Saved checkpoint to "/tmp/tmp82ufu9vj/mx-mod-0000.params"
# [06/02/2021 07:57:04 INFO 140537759278912] #progress_metric: host=algo-1, completed 4.0 % of epochs
# #metrics {"StartTime": 1622620624.071356, "EndTime": 1622620624.2775705, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 83.0, "count": 1, "min": 83, "max": 83}, "Total Batches Seen": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 07:57:04 INFO 140537759278912] #throughput_metric: host=algo-1, train throughput=125.97835589852595 records/second
# [2021-06-02 07:57:04.421] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 143, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620624.4217558, "EndTime": 1622620624.4218483, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8242987442016602, "count": 1, "min": 0.8242987442016602, "max": 0.8242987442016602}}}
#
# #metrics {"StartTime": 1622620624.4219391, "EndTime": 1622620624.4219537, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8442750453948975, "count": 1, "min": 0.8442750453948975, "max": 0.8442750453948975}}}
#
# #metrics {"StartTime": 1622620624.421994, "EndTime": 1622620624.4220047, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.826729326248169, "count": 1, "min": 0.826729326248169, "max": 0.826729326248169}}}
#
# #metrics {"StartTime": 1622620624.4220412, "EndTime": 1622620624.4220514, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.843249683380127, "count": 1, "min": 0.843249683380127, "max": 0.843249683380127}}}
#
# #metrics {"StartTime": 1622620624.4220862, "EndTime": 1622620624.422096, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20179739952087403, "count": 1, "min": 0.20179739952087403, "max": 0.20179739952087403}}}
#
# #metrics {"StartTime": 1622620624.4221313, "EndTime": 1622620624.4221406, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20509454727172852, "count": 1, "min": 0.20509454727172852, "max": 0.20509454727172852}}}
#
# #metrics {"StartTime": 1622620624.4221754, "EndTime": 1622620624.4221852, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.21177355766296388, "count": 1, "min": 0.21177355766296388, "max": 0.21177355766296388}}}
#
# #metrics {"StartTime": 1622620624.4222224, "EndTime": 1622620624.4222324, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2453465962409973, "count": 1, "min": 0.2453465962409973, "max": 0.2453465962409973}}}
#
# #metrics {"StartTime": 1622620624.422267, "EndTime": 1622620624.4222765, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8806359672546387, "count": 1, "min": 0.8806359672546387, "max": 0.8806359672546387}}}
#
# #metrics {"StartTime": 1622620624.4223106, "EndTime": 1622620624.4223201, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8120884037017823, "count": 1, "min": 0.8120884037017823, "max": 0.8120884037017823}}}
#
# #metrics {"StartTime": 1622620624.422354, "EndTime": 1622620624.4223638, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8189279842376709, "count": 1, "min": 0.8189279842376709, "max": 0.8189279842376709}}}
#
# #metrics {"StartTime": 1622620624.4223976, "EndTime": 1622620624.4224072, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8039108562469482, "count": 1, "min": 0.8039108562469482, "max": 0.8039108562469482}}}
#
# #metrics {"StartTime": 1622620624.4224412, "EndTime": 1622620624.422451, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20357991695404054, "count": 1, "min": 0.20357991695404054, "max": 0.20357991695404054}}}
#
# #metrics {"StartTime": 1622620624.4224849, "EndTime": 1622620624.4224946, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3027788162231445, "count": 1, "min": 0.3027788162231445, "max": 0.3027788162231445}}}
#
# #metrics {"StartTime": 1622620624.4225285, "EndTime": 1622620624.422538, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20329114198684692, "count": 1, "min": 0.20329114198684692, "max": 0.20329114198684692}}}
#
# #metrics {"StartTime": 1622620624.4225721, "EndTime": 1622620624.4225817, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2087265992164612, "count": 1, "min": 0.2087265992164612, "max": 0.2087265992164612}}}
#
# #metrics {"StartTime": 1622620624.4226155, "EndTime": 1622620624.422625, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7882349681854248, "count": 1, "min": 0.7882349681854248, "max": 0.7882349681854248}}}
#
# #metrics {"StartTime": 1622620624.422659, "EndTime": 1622620624.4226682, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8396374797821045, "count": 1, "min": 0.8396374797821045, "max": 0.8396374797821045}}}
#
# #metrics {"StartTime": 1622620624.422702, "EndTime": 1622620624.4227116, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8154204654693603, "count": 1, "min": 0.8154204654693603, "max": 0.8154204654693603}}}
#
# #metrics {"StartTime": 1622620624.4227471, "EndTime": 1622620624.422757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8126184844970703, "count": 1, "min": 0.8126184844970703, "max": 0.8126184844970703}}}
#
# #metrics {"StartTime": 1622620624.422791, "EndTime": 1622620624.4228005, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2620376539230347, "count": 1, "min": 0.2620376539230347, "max": 0.2620376539230347}}}
#
# #metrics {"StartTime": 1622620624.4228344, "EndTime": 1622620624.422844, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2655638360977173, "count": 1, "min": 0.2655638360977173, "max": 0.2655638360977173}}}
#
# #metrics {"StartTime": 1622620624.4228776, "EndTime": 1622620624.422887, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2665154600143433, "count": 1, "min": 0.2665154600143433, "max": 0.2665154600143433}}}
#
# #metrics {"StartTime": 1622620624.4229205, "EndTime": 1622620624.42293, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33890653610229493, "count": 1, "min": 0.33890653610229493, "max": 0.33890653610229493}}}
#
# #metrics {"StartTime": 1622620624.4229949, "EndTime": 1622620624.423008, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.871562910079956, "count": 1, "min": 0.871562910079956, "max": 0.871562910079956}}}
#
# #metrics {"StartTime": 1622620624.4230454, "EndTime": 1622620624.4230554, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8663798809051514, "count": 1, "min": 0.8663798809051514, "max": 0.8663798809051514}}}
#
# #metrics {"StartTime": 1622620624.4230938, "EndTime": 1622620624.4231038, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8654977321624756, "count": 1, "min": 0.8654977321624756, "max": 0.8654977321624756}}}
#
# #metrics {"StartTime": 1622620624.4231381, "EndTime": 1622620624.4231474, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8751721954345704, "count": 1, "min": 0.8751721954345704, "max": 0.8751721954345704}}}
#
# #metrics {"StartTime": 1622620624.4231825, "EndTime": 1622620624.4231925, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8977360439300537, "count": 1, "min": 0.8977360439300537, "max": 0.8977360439300537}}}
#
# #metrics {"StartTime": 1622620624.4232266, "EndTime": 1622620624.4232364, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8992594337463379, "count": 1, "min": 0.8992594337463379, "max": 0.8992594337463379}}}
#
# #metrics {"StartTime": 1622620624.4232733, "EndTime": 1622620624.423285, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8880680274963378, "count": 1, "min": 0.8880680274963378, "max": 0.8880680274963378}}}
#
# #metrics {"StartTime": 1622620624.4233139, "EndTime": 1622620624.4233215, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.876504545211792, "count": 1, "min": 0.876504545211792, "max": 0.876504545211792}}}
#
# [06/02/2021 07:57:04 INFO 140537759278912] #quality_metric: host=algo-1, epoch=2, train absolute_loss_objective <loss>=0.8242987442016602
# [06/02/2021 07:57:04 INFO 140537759278912] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=absolute_loss_objective, value=0.20179739952087403
# [06/02/2021 07:57:04 INFO 140537759278912] Epoch 2: Loss improved. Updating best model
# [06/02/2021 07:57:04 INFO 140537759278912] Saving model for epoch: 2
# [06/02/2021 07:57:04 INFO 140537759278912] Saved checkpoint to "/tmp/tmpn2i_w_zt/mx-mod-0000.params"
# [06/02/2021 07:57:04 INFO 140537759278912] #progress_metric: host=algo-1, completed 6.0 % of epochs
# #metrics {"StartTime": 1622620624.2779064, "EndTime": 1622620624.4334385, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 109.0, "count": 1, "min": 109, "max": 109}, "Total Batches Seen": {"sum": 25.0, "count": 1, "min": 25, "max": 25}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 07:57:04 INFO 140537759278912] #throughput_metric: host=algo-1, train throughput=167.01570731946384 records/second
# [2021-06-02 07:57:04.576] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 142, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620624.576582, "EndTime": 1622620624.5766814, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7938915824890137, "count": 1, "min": 0.7938915824890137, "max": 0.7938915824890137}}}
#
# #metrics {"StartTime": 1622620624.576776, "EndTime": 1622620624.5767984, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8135607719421387, "count": 1, "min": 0.8135607719421387, "max": 0.8135607719421387}}}
#
# #metrics {"StartTime": 1622620624.5768576, "EndTime": 1622620624.5768769, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7963221836090087, "count": 1, "min": 0.7963221836090087, "max": 0.7963221836090087}}}
#
# #metrics {"StartTime": 1622620624.5769348, "EndTime": 1622620624.5769534, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8125353431701661, "count": 1, "min": 0.8125353431701661, "max": 0.8125353431701661}}}
#
# #metrics {"StartTime": 1622620624.577009, "EndTime": 1622620624.5770268, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.300389199256897, "count": 1, "min": 0.300389199256897, "max": 0.300389199256897}}}
#
# #metrics {"StartTime": 1622620624.5770807, "EndTime": 1622620624.5770972, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2947694158554077, "count": 1, "min": 0.2947694158554077, "max": 0.2947694158554077}}}
#
# #metrics {"StartTime": 1622620624.577151, "EndTime": 1622620624.577167, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.34739300966262815, "count": 1, "min": 0.34739300966262815, "max": 0.34739300966262815}}}
#
# #metrics {"StartTime": 1622620624.577223, "EndTime": 1622620624.5772412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.31880349159240723, "count": 1, "min": 0.31880349159240723, "max": 0.31880349159240723}}}
#
# #metrics {"StartTime": 1622620624.577308, "EndTime": 1622620624.5773268, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.850230712890625, "count": 1, "min": 0.850230712890625, "max": 0.850230712890625}}}
#
# #metrics {"StartTime": 1622620624.5773802, "EndTime": 1622620624.577397, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7813770198822021, "count": 1, "min": 0.7813770198822021, "max": 0.7813770198822021}}}
#
# #metrics {"StartTime": 1622620624.57745, "EndTime": 1622620624.5774653, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7885236358642578, "count": 1, "min": 0.7885236358642578, "max": 0.7885236358642578}}}
#
# #metrics {"StartTime": 1622620624.577518, "EndTime": 1622620624.5775342, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7731996059417725, "count": 1, "min": 0.7731996059417725, "max": 0.7731996059417725}}}
#
# #metrics {"StartTime": 1622620624.5775905, "EndTime": 1622620624.5776079, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.28878944873809814, "count": 1, "min": 0.28878944873809814, "max": 0.28878944873809814}}}
#
# #metrics {"StartTime": 1622620624.577662, "EndTime": 1622620624.5776777, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.32330681800842287, "count": 1, "min": 0.32330681800842287, "max": 0.32330681800842287}}}
#
# #metrics {"StartTime": 1622620624.5777314, "EndTime": 1622620624.577747, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2900800657272339, "count": 1, "min": 0.2900800657272339, "max": 0.2900800657272339}}}
#
# ...
# #metrics {"StartTime": 1622620627.2092307, "EndTime": 1622620627.3251238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 551.0, "count": 1, "min": 551, "max": 551}, "Total Batches Seen": {"sum": 127.0, "count": 1, "min": 127, "max": 127}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 22.0, "count": 1, "min": 22, "max": 22}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 07:57:07 INFO 140537759278912] #throughput_metric: host=algo-1, train throughput=224.09153378267303 records/second
# [2021-06-02 07:57:07.446] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 44, "duration": 121, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620627.4469576, "EndTime": 1622620627.4470458, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4893594980239868, "count": 1, "min": 0.4893594980239868, "max": 0.4893594980239868}}}
#
# #metrics {"StartTime": 1622620627.447164, "EndTime": 1622620627.447185, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4900112867355347, "count": 1, "min": 0.4900112867355347, "max": 0.4900112867355347}}}
#
# #metrics {"StartTime": 1622620627.447239, "EndTime": 1622620627.4472554, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.49294668674468994, "count": 1, "min": 0.49294668674468994, "max": 0.49294668674468994}}}
#
# #metrics {"StartTime": 1622620627.4473057, "EndTime": 1622620627.4473226, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4891304636001587, "count": 1, "min": 0.4891304636001587, "max": 0.4891304636001587}}}
#
# #metrics {"StartTime": 1622620627.4473765, "EndTime": 1622620627.4473932, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.17494748592376708, "count": 1, "min": 0.17494748592376708, "max": 0.17494748592376708}}}
#
# #metrics {"StartTime": 1622620627.4474485, "EndTime": 1622620627.4474657, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.19594470977783204, "count": 1, "min": 0.19594470977783204, "max": 0.19594470977783204}}}
#
# #metrics {"StartTime": 1622620627.447518, "EndTime": 1622620627.4475353, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2998981499671936, "count": 1, "min": 0.2998981499671936, "max": 0.2998981499671936}}}
#
# #metrics {"StartTime": 1622620627.447586, "EndTime": 1622620627.4476025, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20681100845336914, "count": 1, "min": 0.20681100845336914, "max": 0.20681100845336914}}}
#
# #metrics {"StartTime": 1622620627.4476528, "EndTime": 1622620627.4476693, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5410200023651123, "count": 1, "min": 0.5410200023651123, "max": 0.5410200023651123}}}
#
# #metrics {"StartTime": 1622620627.447722, "EndTime": 1622620627.4477398, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.462733473777771, "count": 1, "min": 0.462733473777771, "max": 0.462733473777771}}}
#
# #metrics {"StartTime": 1622620627.447793, "EndTime": 1622620627.4478092, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4851375436782837, "count": 1, "min": 0.4851375436782837, "max": 0.4851375436782837}}}
#
# #metrics {"StartTime": 1622620627.4478612, "EndTime": 1622620627.4478781, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4561898565292358, "count": 1, "min": 0.4561898565292358, "max": 0.4561898565292358}}}
#
# #metrics {"StartTime": 1622620627.4479299, "EndTime": 1622620627.4479465, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3182308840751648, "count": 1, "min": 0.3182308840751648, "max": 0.3182308840751648}}}
#
# #metrics {"StartTime": 1622620627.4479969, "EndTime": 1622620627.448014, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.22247365474700928, "count": 1, "min": 0.22247365474700928, "max": 0.22247365474700928}}}
#
# #metrics {"StartTime": 1622620627.4480667, "EndTime": 1622620627.4480824, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.31794546604156493, "count": 1, "min": 0.31794546604156493, "max": 0.31794546604156493}}}
#
# #metrics {"StartTime": 1622620627.4481308, "EndTime": 1622620627.4481463, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.28646833896636964, "count": 1, "min": 0.28646833896636964, "max": 0.28646833896636964}}}
#
# #metrics {"StartTime": 1622620627.4481976, "EndTime": 1622620627.448214, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5072611045837402, "count": 1, "min": 0.5072611045837402, "max": 0.5072611045837402}}}
#
# #metrics {"StartTime": 1622620627.4482677, "EndTime": 1622620627.448284, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5370547914505005, "count": 1, "min": 0.5370547914505005, "max": 0.5370547914505005}}}
#
# #metrics {"StartTime": 1622620627.4483361, "EndTime": 1622620627.4483526, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.530392370223999, "count": 1, "min": 0.530392370223999, "max": 0.530392370223999}}}
#
# #metrics {"StartTime": 1622620627.448404, "EndTime": 1622620627.4484196, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5168305397033691, "count": 1, "min": 0.5168305397033691, "max": 0.5168305397033691}}}
#
# #metrics {"StartTime": 1622620627.4484704, "EndTime": 1622620627.448486, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2695962572097778, "count": 1, "min": 0.2695962572097778, "max": 0.2695962572097778}}}
#
# #metrics {"StartTime": 1622620627.4485347, "EndTime": 1622620627.44855, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.25803170680999754, "count": 1, "min": 0.25803170680999754, "max": 0.25803170680999754}}}
#
# #metrics {"StartTime": 1622620627.4486022, "EndTime": 1622620627.4486194, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.30544314861297606, "count": 1, "min": 0.30544314861297606, "max": 0.30544314861297606}}}
#
# #metrics {"StartTime": 1622620627.4486732, "EndTime": 1622620627.448689, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3154701089859009, "count": 1, "min": 0.3154701089859009, "max": 0.3154701089859009}}}
#
# #metrics {"StartTime": 1622620627.4487395, "EndTime": 1622620627.448756, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8582065010070801, "count": 1, "min": 0.8582065010070801, "max": 0.8582065010070801}}}
#
# #metrics {"StartTime": 1622620627.4488096, "EndTime": 1622620627.4488251, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8581342792510986, "count": 1, "min": 0.8581342792510986, "max": 0.8581342792510986}}}
#
# #metrics {"StartTime": 1622620627.4488745, "EndTime": 1622620627.4488914, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8588011074066162, "count": 1, "min": 0.8588011074066162, "max": 0.8588011074066162}}}
#
# #metrics {"StartTime": 1622620627.448945, "EndTime": 1622620627.4489622, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8576299858093261, "count": 1, "min": 0.8576299858093261, "max": 0.8576299858093261}}}
#
# #metrics {"StartTime": 1622620627.4490156, "EndTime": 1622620627.4490314, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8785705947875977, "count": 1, "min": 0.8785705947875977, "max": 0.8785705947875977}}}
#
# #metrics {"StartTime": 1622620627.4490826, "EndTime": 1622620627.4490986, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8842523384094239, "count": 1, "min": 0.8842523384094239, "max": 0.8842523384094239}}}
#
# #metrics {"StartTime": 1622620627.4491494, "EndTime": 1622620627.4491658, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.877989501953125, "count": 1, "min": 0.877989501953125, "max": 0.877989501953125}}}
#
# #metrics {"StartTime": 1622620627.4492238, "EndTime": 1622620627.4492412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8801961803436279, "count": 1, "min": 0.8801961803436279, "max": 0.8801961803436279}}}
#
# [06/02/2021 07:57:07 INFO 140537759278912] #quality_metric: host=algo-1, epoch=20, train absolute_loss_objective <loss>=0.4893594980239868
# [06/02/2021 07:57:07 INFO 140537759278912] #early_stopping_criteria_metric: host=algo-1, epoch=20, criteria=absolute_loss_objective, value=0.17494748592376708
# [06/02/2021 07:57:07 INFO 140537759278912] Saving model for epoch: 20
# [06/02/2021 07:57:07 INFO 140537759278912] Saved checkpoint to "/tmp/tmp9eitrkgu/mx-mod-0000.params"
# [06/02/2021 07:57:07 INFO 140537759278912] Early stop condition met. Stopping training.
# [06/02/2021 07:57:07 INFO 140537759278912] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1622620627.3254306, "EndTime": 1622620627.458408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 20, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 577.0, "count": 1, "min": 577, "max": 577}, "Total Batches Seen": {"sum": 133.0, "count": 1, "min": 133, "max": 133}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 23.0, "count": 1, "min": 23, "max": 23}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 07:57:07 INFO 140537759278912] #throughput_metric: host=algo-1, train throughput=195.30611572379308 records/second
# [06/02/2021 07:57:07 WARNING 140537759278912] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/02/2021 07:57:07 WARNING 140537759278912] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-06-02 07:57:07.459] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 46, "duration": 0, "num_examples": 1, "num_bytes": 240}
# [2021-06-02 07:57:07.468] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 48, "duration": 6, "num_examples": 6, "num_bytes": 1248}
# [06/02/2021 07:57:07 INFO 140537759278912] #train_score (algo-1) : ('absolute_loss_objective', 7429.611478365385)
# [06/02/2021 07:57:07 INFO 140537759278912] #train_score (algo-1) : ('mse', 73114040.3076923)
# [06/02/2021 07:57:07 INFO 140537759278912] #train_score (algo-1) : ('absolute_loss', 7429.611478365385)
# [06/02/2021 07:57:07 INFO 140537759278912] #quality_metric: host=algo-1, train absolute_loss_objective <loss>=7429.611478365385
# [06/02/2021 07:57:07 INFO 140537759278912] #quality_metric: host=algo-1, train mse <loss>=73114040.3076923
# [06/02/2021 07:57:07 INFO 140537759278912] #quality_metric: host=algo-1, train absolute_loss <loss>=7429.611478365385
# [06/02/2021 07:57:07 INFO 140537759278912] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [06/02/2021 07:57:07 INFO 140537759278912] Saved checkpoint to "/tmp/tmpvya51b50/mx-mod-0000.params"
# [06/02/2021 07:57:07 INFO 140537759278912] Test data is not provided.
# #metrics {"StartTime": 1622620623.702416, "EndTime": 1622620627.4748354, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 193.06278228759766, "count": 1, "min": 193.06278228759766, "max": 193.06278228759766}, "epochs": {"sum": 50.0, "count": 1, "min": 50, "max": 50}, "check_early_stopping.time": {"sum": 15.034914016723633, "count": 21, "min": 0.19931793212890625, "max": 1.873016357421875}, "update.time": {"sum": 3469.160795211792, "count": 21, "min": 113.01708221435547, "max": 206.42971992492676}, "finalize.time": {"sum": 10.97559928894043, "count": 1, "min": 10.97559928894043, "max": 10.97559928894043}, "setuptime": {"sum": 24.187326431274414, "count": 1, "min": 24.187326431274414, "max": 24.187326431274414}, "totaltime": {"sum": 4057.6863288879395, "count": 1, "min": 4057.6863288879395, "max": 4057.6863288879395}}}
#
#
# 2021-06-02 07:57:26 Completed - Training job completed
# Training seconds: 65
# Billable seconds: 65

# %%
# We have pass in the container, the type of instance that we would like to use for training 
# output path and sagemaker session into the Estimator. 
# We can also specify how many instances we would like to use for training
# sagemaker_session = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count = 1, 
                                       train_instance_type = 'ml.c4.xlarge',
                                       output_path = output_location,
                                       sagemaker_session = sagemaker_session)


# We can tune parameters like the number of features that we are passing in, type of predictor like 'regressor' or 'classifier', mini batch size, epochs
# Train 32 different versions of the model and will get the best out of them (built-in parameters optimization!)

linear.set_hyperparameters(feature_dim = 1,
                           predictor_type = 'regressor',
                           mini_batch_size = 5,
                           epochs = 5,
                           num_models = 64,
                           loss = 'absolute_loss')

# Now we are ready to pass in the training data from S3 to train the linear learner model

linear.fit({'train': s3_train_data})

# Let's see the progress using cloudwatch logs
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-06-02 07:57:55 Starting - Starting the training job...
# 2021-06-02 07:58:18 Starting - Launching requested ML instancesProfilerReport-1622620675: InProgress
# ......
# 2021-06-02 07:59:18 Starting - Preparing the instances for training.........
# 2021-06-02 08:00:47 Downloading - Downloading input data
# 2021-06-02 08:00:47 Training - Downloading the training image...
# 2021-06-02 08:01:19 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [06/02/2021 08:01:12 INFO 139728752760640] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [06/02/2021 08:01:12 INFO 139728752760640] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'loss': 'absolute_loss', 'feature_dim': '1', 'num_models': '64', 'predictor_type': 'regressor', 'epochs': '5', 'mini_batch_size': '5'}
# [06/02/2021 08:01:12 INFO 139728752760640] Final configuration: {'mini_batch_size': '5', 'epochs': '5', 'feature_dim': '1', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '64', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'absolute_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [06/02/2021 08:01:12 WARNING 139728752760640] Loggers have already been setup.
# Process 1 is a worker.
# [06/02/2021 08:01:12 INFO 139728752760640] Using default worker.
# [06/02/2021 08:01:13 INFO 139728752760640] Checkpoint loading and saving are disabled.
# [2021-06-02 08:01:13.108] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 14, "num_examples": 1, "num_bytes": 240}
# [06/02/2021 08:01:13 INFO 139728752760640] Create Store: local
# [2021-06-02 08:01:13.171] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 61, "num_examples": 6, "num_bytes": 1248}
# [06/02/2021 08:01:13 INFO 139728752760640] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f14c20a40d0>
# [06/02/2021 08:01:13 INFO 139728752760640] Scaling model computed with parameters:
#  {'stdev_label':
# [31895.934]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [3.4896421]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [79380.4]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [5.7799997]
# <NDArray 1 @cpu(0)>}
# [06/02/2021 08:01:13 INFO 139728752760640] nvidia-smi: took 0.033 seconds to run.
# [06/02/2021 08:01:13 INFO 139728752760640] nvidia-smi identified 0 GPUs.
# [06/02/2021 08:01:13 INFO 139728752760640] Number of GPUs being used: 0
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# [06/02/2021 08:01:13 WARNING 139728752760640] Setting num_models to 32.
# #metrics {"StartTime": 1622620873.2834618, "EndTime": 1622620873.2834992, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Total Batches Seen": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-06-02 08:01:13.418] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 134, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620873.4188821, "EndTime": 1622620873.4189947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8945285511016846, "count": 1, "min": 0.8945285511016846, "max": 0.8945285511016846}}}
#
# #metrics {"StartTime": 1622620873.4191074, "EndTime": 1622620873.419129, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9145934009552001, "count": 1, "min": 0.9145934009552001, "max": 0.9145934009552001}}}
#
# #metrics {"StartTime": 1622620873.4191866, "EndTime": 1622620873.4192047, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8969591331481933, "count": 1, "min": 0.8969591331481933, "max": 0.8969591331481933}}}
#
# #metrics {"StartTime": 1622620873.4192593, "EndTime": 1622620873.4192765, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9135679912567138, "count": 1, "min": 0.9135679912567138, "max": 0.9135679912567138}}}
#
# #metrics {"StartTime": 1622620873.419331, "EndTime": 1622620873.4193475, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7887770366668702, "count": 1, "min": 0.7887770366668702, "max": 0.7887770366668702}}}
#
# #metrics {"StartTime": 1622620873.419398, "EndTime": 1622620873.419415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7973329544067382, "count": 1, "min": 0.7973329544067382, "max": 0.7973329544067382}}}
#
# #metrics {"StartTime": 1622620873.419472, "EndTime": 1622620873.4194887, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8596661376953125, "count": 1, "min": 0.8596661376953125, "max": 0.8596661376953125}}}
#
# #metrics {"StartTime": 1622620873.41954, "EndTime": 1622620873.4195561, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8193386936187744, "count": 1, "min": 0.8193386936187744, "max": 0.8193386936187744}}}
#
# #metrics {"StartTime": 1622620873.4196076, "EndTime": 1622620873.4196227, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9508654689788818, "count": 1, "min": 0.9508654689788818, "max": 0.9508654689788818}}}
#
# #metrics {"StartTime": 1622620873.4196732, "EndTime": 1622620873.419689, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8824044704437256, "count": 1, "min": 0.8824044704437256, "max": 0.8824044704437256}}}
#
# #metrics {"StartTime": 1622620873.4197407, "EndTime": 1622620873.419757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8891557693481446, "count": 1, "min": 0.8891557693481446, "max": 0.8891557693481446}}}
#
# #metrics {"StartTime": 1622620873.4198086, "EndTime": 1622620873.4198241, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.874226713180542, "count": 1, "min": 0.874226713180542, "max": 0.874226713180542}}}
#
# #metrics {"StartTime": 1622620873.419875, "EndTime": 1622620873.4198906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7966775894165039, "count": 1, "min": 0.7966775894165039, "max": 0.7966775894165039}}}
#
# #metrics {"StartTime": 1622620873.4199464, "EndTime": 1622620873.419963, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8014877033233643, "count": 1, "min": 0.8014877033233643, "max": 0.8014877033233643}}}
#
# #metrics {"StartTime": 1622620873.4200146, "EndTime": 1622620873.4200313, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.795371904373169, "count": 1, "min": 0.795371904373169, "max": 0.795371904373169}}}
#
# #metrics {"StartTime": 1622620873.420082, "EndTime": 1622620873.4200983, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.798916072845459, "count": 1, "min": 0.798916072845459, "max": 0.798916072845459}}}
#
# #metrics {"StartTime": 1622620873.4201484, "EndTime": 1622620873.4201639, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8581383895874023, "count": 1, "min": 0.8581383895874023, "max": 0.8581383895874023}}}
#
# #metrics {"StartTime": 1622620873.4202137, "EndTime": 1622620873.42023, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9098024272918701, "count": 1, "min": 0.9098024272918701, "max": 0.9098024272918701}}}
#
# #metrics {"StartTime": 1622620873.4202814, "EndTime": 1622620873.4202983, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8854198932647706, "count": 1, "min": 0.8854198932647706, "max": 0.8854198932647706}}}
#
# #metrics {"StartTime": 1622620873.4203494, "EndTime": 1622620873.4203653, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.882696361541748, "count": 1, "min": 0.882696361541748, "max": 0.882696361541748}}}
#
# #metrics {"StartTime": 1622620873.4204154, "EndTime": 1622620873.420431, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8169410800933838, "count": 1, "min": 0.8169410800933838, "max": 0.8169410800933838}}}
#
# #metrics {"StartTime": 1622620873.4204793, "EndTime": 1622620873.420495, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8294430732727051, "count": 1, "min": 0.8294430732727051, "max": 0.8294430732727051}}}
#
# #metrics {"StartTime": 1622620873.4205465, "EndTime": 1622620873.4205644, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.806483097076416, "count": 1, "min": 0.806483097076416, "max": 0.806483097076416}}}
#
# #metrics {"StartTime": 1622620873.4206152, "EndTime": 1622620873.4206305, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8643637561798095, "count": 1, "min": 0.8643637561798095, "max": 0.8643637561798095}}}
#
# #metrics {"StartTime": 1622620873.4206796, "EndTime": 1622620873.420693, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8610915470123292, "count": 1, "min": 0.8610915470123292, "max": 0.8610915470123292}}}
#
# #metrics {"StartTime": 1622620873.4207394, "EndTime": 1622620873.420755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9281379318237305, "count": 1, "min": 0.9281379318237305, "max": 0.9281379318237305}}}
#
# #metrics {"StartTime": 1622620873.420805, "EndTime": 1622620873.4208207, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9147527980804443, "count": 1, "min": 0.9147527980804443, "max": 0.9147527980804443}}}
#
# #metrics {"StartTime": 1622620873.4208722, "EndTime": 1622620873.420888, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9040926551818848, "count": 1, "min": 0.9040926551818848, "max": 0.9040926551818848}}}
#
# #metrics {"StartTime": 1622620873.420941, "EndTime": 1622620873.4209573, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9367700004577637, "count": 1, "min": 0.9367700004577637, "max": 0.9367700004577637}}}
#
# #metrics {"StartTime": 1622620873.4210076, "EndTime": 1622620873.4210234, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9380142688751221, "count": 1, "min": 0.9380142688751221, "max": 0.9380142688751221}}}
#
# #metrics {"StartTime": 1622620873.4210732, "EndTime": 1622620873.421089, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9642893409729004, "count": 1, "min": 0.9642893409729004, "max": 0.9642893409729004}}}
#
# #metrics {"StartTime": 1622620873.4211407, "EndTime": 1622620873.4211564, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9633904552459717, "count": 1, "min": 0.9633904552459717, "max": 0.9633904552459717}}}
#
# [06/02/2021 08:01:13 INFO 139728752760640] #quality_metric: host=algo-1, epoch=0, train absolute_loss_objective <loss>=0.8945285511016846
# [06/02/2021 08:01:13 INFO 139728752760640] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=absolute_loss_objective, value=0.7887770366668702
# [06/02/2021 08:01:13 INFO 139728752760640] Epoch 0: Loss improved. Updating best model
# [06/02/2021 08:01:13 INFO 139728752760640] Saving model for epoch: 0
# [06/02/2021 08:01:13 INFO 139728752760640] Saved checkpoint to "/tmp/tmpv6kzd3v2/mx-mod-0000.params"
# [06/02/2021 08:01:13 INFO 139728752760640] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1622620873.2838054, "EndTime": 1622620873.4366615, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 57.0, "count": 1, "min": 57, "max": 57}, "Total Batches Seen": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 08:01:13 INFO 139728752760640] #throughput_metric: host=algo-1, train throughput=169.9252435474723 records/second
# [2021-06-02 08:01:13.551] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 113, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620873.551212, "EndTime": 1622620873.551296, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8557912635803223, "count": 1, "min": 0.8557912635803223, "max": 0.8557912635803223}}}
#
# #metrics {"StartTime": 1622620873.5513866, "EndTime": 1622620873.551406, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8758560466766357, "count": 1, "min": 0.8758560466766357, "max": 0.8758560466766357}}}
#
# #metrics {"StartTime": 1622620873.5514657, "EndTime": 1622620873.551482, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8582218074798584, "count": 1, "min": 0.8582218074798584, "max": 0.8582218074798584}}}
#
# #metrics {"StartTime": 1622620873.551539, "EndTime": 1622620873.5515537, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8748306465148926, "count": 1, "min": 0.8748306465148926, "max": 0.8748306465148926}}}
#
# #metrics {"StartTime": 1622620873.5516057, "EndTime": 1622620873.5516222, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4750103092193603, "count": 1, "min": 0.4750103092193603, "max": 0.4750103092193603}}}
#
# #metrics {"StartTime": 1622620873.5516846, "EndTime": 1622620873.551702, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4838706016540527, "count": 1, "min": 0.4838706016540527, "max": 0.4838706016540527}}}
#
# #metrics {"StartTime": 1622620873.5517654, "EndTime": 1622620873.551783, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.42718470573425293, "count": 1, "min": 0.42718470573425293, "max": 0.42718470573425293}}}
#
# #metrics {"StartTime": 1622620873.5518467, "EndTime": 1622620873.5518641, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.568508243560791, "count": 1, "min": 0.568508243560791, "max": 0.568508243560791}}}
#
# #metrics {"StartTime": 1622620873.551926, "EndTime": 1622620873.551943, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9121278762817383, "count": 1, "min": 0.9121278762817383, "max": 0.9121278762817383}}}
#
# #metrics {"StartTime": 1622620873.5520043, "EndTime": 1622620873.5520215, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8436678123474121, "count": 1, "min": 0.8436678123474121, "max": 0.8436678123474121}}}
#
# #metrics {"StartTime": 1622620873.552071, "EndTime": 1622620873.5520852, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8504190254211426, "count": 1, "min": 0.8504190254211426, "max": 0.8504190254211426}}}
#
# #metrics {"StartTime": 1622620873.5521348, "EndTime": 1622620873.55215, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8354901599884034, "count": 1, "min": 0.8354901599884034, "max": 0.8354901599884034}}}
#
# #metrics {"StartTime": 1622620873.5521963, "EndTime": 1622620873.552212, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4834609603881836, "count": 1, "min": 0.4834609603881836, "max": 0.4834609603881836}}}
#
# #metrics {"StartTime": 1622620873.5522695, "EndTime": 1622620873.5522833, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7206231498718262, "count": 1, "min": 0.7206231498718262, "max": 0.7206231498718262}}}
#
# #metrics {"StartTime": 1622620873.552329, "EndTime": 1622620873.5523443, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.48211127281188965, "count": 1, "min": 0.48211127281188965, "max": 0.48211127281188965}}}
#
# #metrics {"StartTime": 1622620873.552393, "EndTime": 1622620873.552409, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5502350234985351, "count": 1, "min": 0.5502350234985351, "max": 0.5502350234985351}}}
#
# #metrics {"StartTime": 1622620873.5524566, "EndTime": 1622620873.5524728, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.81951247215271, "count": 1, "min": 0.81951247215271, "max": 0.81951247215271}}}
#
# #metrics {"StartTime": 1622620873.5525217, "EndTime": 1622620873.5525377, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8710953235626221, "count": 1, "min": 0.8710953235626221, "max": 0.8710953235626221}}}
#
# #metrics {"StartTime": 1622620873.5525901, "EndTime": 1622620873.5526052, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8467490863800049, "count": 1, "min": 0.8467490863800049, "max": 0.8467490863800049}}}
#
# #metrics {"StartTime": 1622620873.552661, "EndTime": 1622620873.5526764, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8440298080444336, "count": 1, "min": 0.8440298080444336, "max": 0.8440298080444336}}}
#
# #metrics {"StartTime": 1622620873.5527277, "EndTime": 1622620873.552745, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5938818550109863, "count": 1, "min": 0.5938818550109863, "max": 0.5938818550109863}}}
#
# #metrics {"StartTime": 1622620873.5527875, "EndTime": 1622620873.552803, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6028077983856202, "count": 1, "min": 0.6028077983856202, "max": 0.6028077983856202}}}
#
# #metrics {"StartTime": 1622620873.5528657, "EndTime": 1622620873.5528822, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5316579484939575, "count": 1, "min": 0.5316579484939575, "max": 0.5316579484939575}}}
#
# #metrics {"StartTime": 1622620873.5529418, "EndTime": 1622620873.5529592, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.46307676792144775, "count": 1, "min": 0.46307676792144775, "max": 0.46307676792144775}}}
#
# #metrics {"StartTime": 1622620873.5530238, "EndTime": 1622620873.553041, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8644503784179688, "count": 1, "min": 0.8644503784179688, "max": 0.8644503784179688}}}
#
# #metrics {"StartTime": 1622620873.5531008, "EndTime": 1622620873.5531178, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8905514430999756, "count": 1, "min": 0.8905514430999756, "max": 0.8905514430999756}}}
#
# #metrics {"StartTime": 1622620873.553178, "EndTime": 1622620873.5531952, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8799408435821533, "count": 1, "min": 0.8799408435821533, "max": 0.8799408435821533}}}
#
# #metrics {"StartTime": 1622620873.5532575, "EndTime": 1622620873.5532744, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8793697357177734, "count": 1, "min": 0.8793697357177734, "max": 0.8793697357177734}}}
#
# #metrics {"StartTime": 1622620873.5533257, "EndTime": 1622620873.5533392, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9024749660491943, "count": 1, "min": 0.9024749660491943, "max": 0.9024749660491943}}}
#
# #metrics {"StartTime": 1622620873.5533988, "EndTime": 1622620873.553415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9013331985473633, "count": 1, "min": 0.9013331985473633, "max": 0.9013331985473633}}}
#
# #metrics {"StartTime": 1622620873.5534663, "EndTime": 1622620873.5534768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9040912055969238, "count": 1, "min": 0.9040912055969238, "max": 0.9040912055969238}}}
#
# #metrics {"StartTime": 1622620873.553506, "EndTime": 1622620873.553519, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9120360469818115, "count": 1, "min": 0.9120360469818115, "max": 0.9120360469818115}}}
#
# [06/02/2021 08:01:13 INFO 139728752760640] #quality_metric: host=algo-1, epoch=1, train absolute_loss_objective <loss>=0.8557912635803223
# [06/02/2021 08:01:13 INFO 139728752760640] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=absolute_loss_objective, value=0.42718470573425293
# [06/02/2021 08:01:13 INFO 139728752760640] Epoch 1: Loss improved. Updating best model
# [06/02/2021 08:01:13 INFO 139728752760640] Saving model for epoch: 1
# [06/02/2021 08:01:13 INFO 139728752760640] Saved checkpoint to "/tmp/tmpl9p87g02/mx-mod-0000.params"
# [06/02/2021 08:01:13 INFO 139728752760640] #progress_metric: host=algo-1, completed 40.0 % of epochs
# #metrics {"StartTime": 1622620873.4370017, "EndTime": 1622620873.5635881, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 83.0, "count": 1, "min": 83, "max": 83}, "Total Batches Seen": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 08:01:13 INFO 139728752760640] #throughput_metric: host=algo-1, train throughput=205.09195406622257 records/second
# [2021-06-02 08:01:13.687] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 122, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620873.6871176, "EndTime": 1622620873.6872141, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8242987442016602, "count": 1, "min": 0.8242987442016602, "max": 0.8242987442016602}}}
#
# #metrics {"StartTime": 1622620873.687327, "EndTime": 1622620873.6873465, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8442750453948975, "count": 1, "min": 0.8442750453948975, "max": 0.8442750453948975}}}
#
# #metrics {"StartTime": 1622620873.6874046, "EndTime": 1622620873.6874225, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.826729326248169, "count": 1, "min": 0.826729326248169, "max": 0.826729326248169}}}
#
# #metrics {"StartTime": 1622620873.6874766, "EndTime": 1622620873.687493, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.843249683380127, "count": 1, "min": 0.843249683380127, "max": 0.843249683380127}}}
#
# #metrics {"StartTime": 1622620873.6875455, "EndTime": 1622620873.6875613, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20179739952087403, "count": 1, "min": 0.20179739952087403, "max": 0.20179739952087403}}}
#
# #metrics {"StartTime": 1622620873.687615, "EndTime": 1622620873.6876318, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20509454727172852, "count": 1, "min": 0.20509454727172852, "max": 0.20509454727172852}}}
#
# #metrics {"StartTime": 1622620873.6876836, "EndTime": 1622620873.6877, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.21177355766296388, "count": 1, "min": 0.21177355766296388, "max": 0.21177355766296388}}}
#
# #metrics {"StartTime": 1622620873.687752, "EndTime": 1622620873.6877685, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2453465962409973, "count": 1, "min": 0.2453465962409973, "max": 0.2453465962409973}}}
#
# #metrics {"StartTime": 1622620873.6878195, "EndTime": 1622620873.6878364, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8806359672546387, "count": 1, "min": 0.8806359672546387, "max": 0.8806359672546387}}}
#
# #metrics {"StartTime": 1622620873.687886, "EndTime": 1622620873.6879015, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8120884037017823, "count": 1, "min": 0.8120884037017823, "max": 0.8120884037017823}}}
#
# #metrics {"StartTime": 1622620873.687951, "EndTime": 1622620873.6879673, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8189279842376709, "count": 1, "min": 0.8189279842376709, "max": 0.8189279842376709}}}
#
# #metrics {"StartTime": 1622620873.6880174, "EndTime": 1622620873.688034, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8039108562469482, "count": 1, "min": 0.8039108562469482, "max": 0.8039108562469482}}}
#
# #metrics {"StartTime": 1622620873.6880836, "EndTime": 1622620873.688099, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20357991695404054, "count": 1, "min": 0.20357991695404054, "max": 0.20357991695404054}}}
#
# #metrics {"StartTime": 1622620873.6881478, "EndTime": 1622620873.6881633, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3027788162231445, "count": 1, "min": 0.3027788162231445, "max": 0.3027788162231445}}}
#
# #metrics {"StartTime": 1622620873.6882145, "EndTime": 1622620873.68823, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20329114198684692, "count": 1, "min": 0.20329114198684692, "max": 0.20329114198684692}}}
#
# #metrics {"StartTime": 1622620873.6882813, "EndTime": 1622620873.6882973, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2087265992164612, "count": 1, "min": 0.2087265992164612, "max": 0.2087265992164612}}}
#
# #metrics {"StartTime": 1622620873.6883485, "EndTime": 1622620873.6883643, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7882349681854248, "count": 1, "min": 0.7882349681854248, "max": 0.7882349681854248}}}
#
# #metrics {"StartTime": 1622620873.6884177, "EndTime": 1622620873.6884348, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8396374797821045, "count": 1, "min": 0.8396374797821045, "max": 0.8396374797821045}}}
#
# #metrics {"StartTime": 1622620873.6884868, "EndTime": 1622620873.6885028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8154204654693603, "count": 1, "min": 0.8154204654693603, "max": 0.8154204654693603}}}
#
# #metrics {"StartTime": 1622620873.688554, "EndTime": 1622620873.6885695, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8126184844970703, "count": 1, "min": 0.8126184844970703, "max": 0.8126184844970703}}}
#
# #metrics {"StartTime": 1622620873.688624, "EndTime": 1622620873.68864, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2620376539230347, "count": 1, "min": 0.2620376539230347, "max": 0.2620376539230347}}}
#
# #metrics {"StartTime": 1622620873.688691, "EndTime": 1622620873.6887078, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2655638360977173, "count": 1, "min": 0.2655638360977173, "max": 0.2655638360977173}}}
#
# #metrics {"StartTime": 1622620873.6887593, "EndTime": 1622620873.688774, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2665154600143433, "count": 1, "min": 0.2665154600143433, "max": 0.2665154600143433}}}
#
# #metrics {"StartTime": 1622620873.6888242, "EndTime": 1622620873.6888394, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33890653610229493, "count": 1, "min": 0.33890653610229493, "max": 0.33890653610229493}}}
#
# #metrics {"StartTime": 1622620873.6888905, "EndTime": 1622620873.6889064, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.871562910079956, "count": 1, "min": 0.871562910079956, "max": 0.871562910079956}}}
#
# #metrics {"StartTime": 1622620873.6889591, "EndTime": 1622620873.6889756, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8663798809051514, "count": 1, "min": 0.8663798809051514, "max": 0.8663798809051514}}}
#
# #metrics {"StartTime": 1622620873.689029, "EndTime": 1622620873.689045, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8654977321624756, "count": 1, "min": 0.8654977321624756, "max": 0.8654977321624756}}}
#
# #metrics {"StartTime": 1622620873.6890955, "EndTime": 1622620873.6891112, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8751721954345704, "count": 1, "min": 0.8751721954345704, "max": 0.8751721954345704}}}
#
# #metrics {"StartTime": 1622620873.6891632, "EndTime": 1622620873.6891797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8977360439300537, "count": 1, "min": 0.8977360439300537, "max": 0.8977360439300537}}}
#
# #metrics {"StartTime": 1622620873.6892319, "EndTime": 1622620873.689247, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8992594337463379, "count": 1, "min": 0.8992594337463379, "max": 0.8992594337463379}}}
#
# #metrics {"StartTime": 1622620873.6892967, "EndTime": 1622620873.6893122, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8880680274963378, "count": 1, "min": 0.8880680274963378, "max": 0.8880680274963378}}}
#
# #metrics {"StartTime": 1622620873.68937, "EndTime": 1622620873.6893866, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.876504545211792, "count": 1, "min": 0.876504545211792, "max": 0.876504545211792}}}
#
# [06/02/2021 08:01:13 INFO 139728752760640] #quality_metric: host=algo-1, epoch=2, train absolute_loss_objective <loss>=0.8242987442016602
# [06/02/2021 08:01:13 INFO 139728752760640] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=absolute_loss_objective, value=0.20179739952087403
# [06/02/2021 08:01:13 INFO 139728752760640] Epoch 2: Loss improved. Updating best model
# [06/02/2021 08:01:13 INFO 139728752760640] Saving model for epoch: 2
# [06/02/2021 08:01:13 INFO 139728752760640] Saved checkpoint to "/tmp/tmp17qvzr02/mx-mod-0000.params"
# [06/02/2021 08:01:13 INFO 139728752760640] #progress_metric: host=algo-1, completed 60.0 % of epochs
# #metrics {"StartTime": 1622620873.5639265, "EndTime": 1622620873.6998134, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 109.0, "count": 1, "min": 109, "max": 109}, "Total Batches Seen": {"sum": 25.0, "count": 1, "min": 25, "max": 25}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 08:01:13 INFO 139728752760640] #throughput_metric: host=algo-1, train throughput=191.1326916201039 records/second
# [2021-06-02 08:01:13.824] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 124, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620873.824893, "EndTime": 1622620873.824994, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7938915824890137, "count": 1, "min": 0.7938915824890137, "max": 0.7938915824890137}}}
#
# #metrics {"StartTime": 1622620873.8251069, "EndTime": 1622620873.8251278, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8135607719421387, "count": 1, "min": 0.8135607719421387, "max": 0.8135607719421387}}}
#
# #metrics {"StartTime": 1622620873.8251958, "EndTime": 1622620873.825214, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7963221836090087, "count": 1, "min": 0.7963221836090087, "max": 0.7963221836090087}}}
#
# #metrics {"StartTime": 1622620873.8252723, "EndTime": 1622620873.8252897, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8125353431701661, "count": 1, "min": 0.8125353431701661, "max": 0.8125353431701661}}}
#
# #metrics {"StartTime": 1622620873.825348, "EndTime": 1622620873.8253653, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.300389199256897, "count": 1, "min": 0.300389199256897, "max": 0.300389199256897}}}
#
# #metrics {"StartTime": 1622620873.8254201, "EndTime": 1622620873.8254366, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2947694158554077, "count": 1, "min": 0.2947694158554077, "max": 0.2947694158554077}}}
#
# #metrics {"StartTime": 1622620873.8254907, "EndTime": 1622620873.8255076, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.34739300966262815, "count": 1, "min": 0.34739300966262815, "max": 0.34739300966262815}}}
#
# #metrics {"StartTime": 1622620873.8255599, "EndTime": 1622620873.8255758, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.31880349159240723, "count": 1, "min": 0.31880349159240723, "max": 0.31880349159240723}}}
#
# #metrics {"StartTime": 1622620873.825627, "EndTime": 1622620873.8256443, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.850230712890625, "count": 1, "min": 0.850230712890625, "max": 0.850230712890625}}}
#
# #metrics {"StartTime": 1622620873.8256967, "EndTime": 1622620873.8257134, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7813770198822021, "count": 1, "min": 0.7813770198822021, "max": 0.7813770198822021}}}
#
# #metrics {"StartTime": 1622620873.825766, "EndTime": 1622620873.8257823, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7885236358642578, "count": 1, "min": 0.7885236358642578, "max": 0.7885236358642578}}}
#
# #metrics {"StartTime": 1622620873.8258338, "EndTime": 1622620873.825849, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7731996059417725, "count": 1, "min": 0.7731996059417725, "max": 0.7731996059417725}}}
#
# ...
# [06/02/2021 08:01:13 INFO 139728752760640] Saved checkpoint to "/tmp/tmpnra14tfn/mx-mod-0000.params"
# [06/02/2021 08:01:13 INFO 139728752760640] #progress_metric: host=algo-1, completed 80.0 % of epochs
# #metrics {"StartTime": 1622620873.7001314, "EndTime": 1622620873.8374517, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 135.0, "count": 1, "min": 135, "max": 135}, "Total Batches Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 08:01:13 INFO 139728752760640] #throughput_metric: host=algo-1, train throughput=189.11510934841834 records/second
# [2021-06-02 08:01:13.958] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 12, "duration": 120, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622620873.958163, "EndTime": 1622620873.9582503, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7723214626312256, "count": 1, "min": 0.7723214626312256, "max": 0.7723214626312256}}}
#
# #metrics {"StartTime": 1622620873.9583461, "EndTime": 1622620873.958366, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7900911426544189, "count": 1, "min": 0.7900911426544189, "max": 0.7900911426544189}}}
#
# #metrics {"StartTime": 1622620873.9584181, "EndTime": 1622620873.9584339, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7745308399200439, "count": 1, "min": 0.7745308399200439, "max": 0.7745308399200439}}}
#
# #metrics {"StartTime": 1622620873.9584877, "EndTime": 1622620873.958503, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7891590690612793, "count": 1, "min": 0.7891590690612793, "max": 0.7891590690612793}}}
#
# #metrics {"StartTime": 1622620873.9585655, "EndTime": 1622620873.9585834, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2534684824943543, "count": 1, "min": 0.2534684824943543, "max": 0.2534684824943543}}}
#
# #metrics {"StartTime": 1622620873.9586427, "EndTime": 1622620873.9586694, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2497752094268799, "count": 1, "min": 0.2497752094268799, "max": 0.2497752094268799}}}
#
# #metrics {"StartTime": 1622620873.958726, "EndTime": 1622620873.958742, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3031576108932495, "count": 1, "min": 0.3031576108932495, "max": 0.3031576108932495}}}
#
# #metrics {"StartTime": 1622620873.9587924, "EndTime": 1622620873.9588094, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.22437820196151734, "count": 1, "min": 0.22437820196151734, "max": 0.22437820196151734}}}
#
# #metrics {"StartTime": 1622620873.9588618, "EndTime": 1622620873.9588797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.825195255279541, "count": 1, "min": 0.825195255279541, "max": 0.825195255279541}}}
#
# #metrics {"StartTime": 1622620873.9589338, "EndTime": 1622620873.9589496, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7608409309387207, "count": 1, "min": 0.7608409309387207, "max": 0.7608409309387207}}}
#
# #metrics {"StartTime": 1622620873.959003, "EndTime": 1622620873.9590187, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7674464607238769, "count": 1, "min": 0.7674464607238769, "max": 0.7674464607238769}}}
#
# #metrics {"StartTime": 1622620873.9590647, "EndTime": 1622620873.9590797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7534078311920166, "count": 1, "min": 0.7534078311920166, "max": 0.7534078311920166}}}
#
# #metrics {"StartTime": 1622620873.9591248, "EndTime": 1622620873.9591374, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.24247640371322632, "count": 1, "min": 0.24247640371322632, "max": 0.24247640371322632}}}
#
# #metrics {"StartTime": 1622620873.9591835, "EndTime": 1622620873.9591985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.29072519063949587, "count": 1, "min": 0.29072519063949587, "max": 0.29072519063949587}}}
#
# #metrics {"StartTime": 1622620873.9592512, "EndTime": 1622620873.9592676, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.24336956262588502, "count": 1, "min": 0.24336956262588502, "max": 0.24336956262588502}}}
#
# #metrics {"StartTime": 1622620873.9593213, "EndTime": 1622620873.959338, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.21867279291152955, "count": 1, "min": 0.21867279291152955, "max": 0.21867279291152955}}}
#
# #metrics {"StartTime": 1622620873.9593923, "EndTime": 1622620873.9594085, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7396121978759765, "count": 1, "min": 0.7396121978759765, "max": 0.7396121978759765}}}
#
# #metrics {"StartTime": 1622620873.9594636, "EndTime": 1622620873.9594796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7865690803527832, "count": 1, "min": 0.7865690803527832, "max": 0.7865690803527832}}}
#
# #metrics {"StartTime": 1622620873.9595315, "EndTime": 1622620873.9595478, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7650337886810302, "count": 1, "min": 0.7650337886810302, "max": 0.7650337886810302}}}
#
# #metrics {"StartTime": 1622620873.9596024, "EndTime": 1622620873.9596186, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7621239376068115, "count": 1, "min": 0.7621239376068115, "max": 0.7621239376068115}}}
#
# #metrics {"StartTime": 1622620873.9596696, "EndTime": 1622620873.959682, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4365283679962158, "count": 1, "min": 0.4365283679962158, "max": 0.4365283679962158}}}
#
# #metrics {"StartTime": 1622620873.9597158, "EndTime": 1622620873.9597294, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4343521785736084, "count": 1, "min": 0.4343521785736084, "max": 0.4343521785736084}}}
#
# #metrics {"StartTime": 1622620873.9597738, "EndTime": 1622620873.9597886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3786530637741089, "count": 1, "min": 0.3786530637741089, "max": 0.3786530637741089}}}
#
# #metrics {"StartTime": 1622620873.959842, "EndTime": 1622620873.9598525, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3593438577651977, "count": 1, "min": 0.3593438577651977, "max": 0.3593438577651977}}}
#
# #metrics {"StartTime": 1622620873.9598987, "EndTime": 1622620873.9599137, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.870873441696167, "count": 1, "min": 0.870873441696167, "max": 0.870873441696167}}}
#
# #metrics {"StartTime": 1622620873.959968, "EndTime": 1622620873.9599783, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8533285999298096, "count": 1, "min": 0.8533285999298096, "max": 0.8533285999298096}}}
#
# #metrics {"StartTime": 1622620873.960022, "EndTime": 1622620873.9600375, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8628853988647461, "count": 1, "min": 0.8628853988647461, "max": 0.8628853988647461}}}
#
# #metrics {"StartTime": 1622620873.9601223, "EndTime": 1622620873.9601417, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8580431938171387, "count": 1, "min": 0.8580431938171387, "max": 0.8580431938171387}}}
#
# #metrics {"StartTime": 1622620873.960194, "EndTime": 1622620873.9602065, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9994428443908692, "count": 1, "min": 0.9994428443908692, "max": 0.9994428443908692}}}
#
# #metrics {"StartTime": 1622620873.9602427, "EndTime": 1622620873.9602566, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0013238525390624, "count": 1, "min": 1.0013238525390624, "max": 1.0013238525390624}}}
#
# #metrics {"StartTime": 1622620873.9603083, "EndTime": 1622620873.960324, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8635519218444824, "count": 1, "min": 0.8635519218444824, "max": 0.8635519218444824}}}
#
# #metrics {"StartTime": 1622620873.9603777, "EndTime": 1622620873.9603937, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8558250045776368, "count": 1, "min": 0.8558250045776368, "max": 0.8558250045776368}}}
#
# [06/02/2021 08:01:13 INFO 139728752760640] #quality_metric: host=algo-1, epoch=4, train absolute_loss_objective <loss>=0.7723214626312256
# [06/02/2021 08:01:13 INFO 139728752760640] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=absolute_loss_objective, value=0.21867279291152955
# [06/02/2021 08:01:13 INFO 139728752760640] Saving model for epoch: 4
# [06/02/2021 08:01:13 INFO 139728752760640] Saved checkpoint to "/tmp/tmplxl7fe1a/mx-mod-0000.params"
# [06/02/2021 08:01:13 INFO 139728752760640] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1622620873.8378162, "EndTime": 1622620873.9697127, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 161.0, "count": 1, "min": 161, "max": 161}, "Total Batches Seen": {"sum": 37.0, "count": 1, "min": 37, "max": 37}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 08:01:13 INFO 139728752760640] #throughput_metric: host=algo-1, train throughput=196.9139029080633 records/second
# [06/02/2021 08:01:13 WARNING 139728752760640] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/02/2021 08:01:13 WARNING 139728752760640] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-06-02 08:01:13.970] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 14, "duration": 0, "num_examples": 1, "num_bytes": 240}
# [2021-06-02 08:01:13.988] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 16, "duration": 15, "num_examples": 6, "num_bytes": 1248}
# [06/02/2021 08:01:13 INFO 139728752760640] #train_score (algo-1) : ('absolute_loss_objective', 8610.715745192309)
# [06/02/2021 08:01:13 INFO 139728752760640] #train_score (algo-1) : ('mse', 103096993.23076923)
# [06/02/2021 08:01:13 INFO 139728752760640] #train_score (algo-1) : ('absolute_loss', 8610.715745192309)
# [06/02/2021 08:01:13 INFO 139728752760640] #quality_metric: host=algo-1, train absolute_loss_objective <loss>=8610.715745192309
# [06/02/2021 08:01:13 INFO 139728752760640] #quality_metric: host=algo-1, train mse <loss>=103096993.23076923
# [06/02/2021 08:01:13 INFO 139728752760640] #quality_metric: host=algo-1, train absolute_loss <loss>=8610.715745192309
# [06/02/2021 08:01:13 INFO 139728752760640] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 1, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [06/02/2021 08:01:13 INFO 139728752760640] Saved checkpoint to "/tmp/tmpvbpk9s4o/mx-mod-0000.params"
# [06/02/2021 08:01:13 INFO 139728752760640] Test data is not provided.
# #metrics {"StartTime": 1622620873.0936263, "EndTime": 1622620874.0033436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 188.7350082397461, "count": 1, "min": 188.7350082397461, "max": 188.7350082397461}, "epochs": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "check_early_stopping.time": {"sum": 5.283594131469727, "count": 5, "min": 0.25463104248046875, "max": 1.3005733489990234}, "update.time": {"sum": 665.0776863098145, "count": 5, "min": 123.48389625549316, "max": 145.38836479187012}, "finalize.time": {"sum": 19.619464874267578, "count": 1, "min": 19.619464874267578, "max": 19.619464874267578}, "setuptime": {"sum": 33.77819061279297, "count": 1, "min": 33.77819061279297, "max": 33.77819061279297}, "totaltime": {"sum": 1151.9370079040527, "count": 1, "min": 1151.9370079040527, "max": 1151.9370079040527}}}
#
#
# 2021-06-02 08:01:39 Completed - Training job completed
# Training seconds: 46
# Billable seconds: 46

# %%
# We have pass in the container, the type of instance that we would like to use for training 
# output path and sagemaker session into the Estimator. 
# We can also specify how many instances we would like to use for training
# sagemaker_session = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count = 1, 
                                       train_instance_type = 'ml.c4.xlarge',
                                       output_path = output_location,
                                       sagemaker_session = sagemaker_session,
                                       train_use_spot_instances = True,
                                       train_max_run = 300,
                                       train_max_wait=600   )


# We can tune parameters like the number of features that we are passing in, type of predictor like 'regressor' or 'classifier', mini batch size, epochs
# Train 32 different versions of the model and will get the best out of them (built-in parameters optimization!)

linear.set_hyperparameters(feature_dim = 1,
                           predictor_type = 'regressor',
                           mini_batch_size = 5,
                           epochs = 5,
                           num_models = 64,
                           loss = 'absolute_loss')

# Now we are ready to pass in the training data from S3 to train the linear learner model

linear.fit({'train': s3_train_data})

# Let's see the progress using cloudwatch logs
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_max_run has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_use_spot_instances has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_max_wait has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-06-02 08:02:08 Starting - Starting the training job...
# 2021-06-02 08:02:09 Starting - Launching requested ML instancesProfilerReport-1622620927: InProgress
# ......
# 2021-06-02 08:03:31 Starting - Preparing the instances for training.........
# 2021-06-02 08:05:08 Downloading - Downloading input data
# 2021-06-02 08:05:08 Training - Downloading the training image...
# 2021-06-02 08:05:39 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [06/02/2021 08:05:33 INFO 140423528630080] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [06/02/2021 08:05:33 INFO 140423528630080] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'loss': 'absolute_loss', 'feature_dim': '1', 'num_models': '64', 'predictor_type': 'regressor', 'epochs': '5', 'mini_batch_size': '5'}
# [06/02/2021 08:05:33 INFO 140423528630080] Final configuration: {'mini_batch_size': '5', 'epochs': '5', 'feature_dim': '1', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '64', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'absolute_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [06/02/2021 08:05:33 WARNING 140423528630080] Loggers have already been setup.
# Process 1 is a worker.
# [06/02/2021 08:05:33 INFO 140423528630080] Using default worker.
# [06/02/2021 08:05:33 INFO 140423528630080] Checkpoint loading and saving are disabled.
# [2021-06-02 08:05:33.874] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 14, "num_examples": 1, "num_bytes": 240}
# [06/02/2021 08:05:33 INFO 140423528630080] Create Store: local
# [2021-06-02 08:05:33.969] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 94, "num_examples": 6, "num_bytes": 1248}
# [06/02/2021 08:05:33 INFO 140423528630080] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fb68591a790>
# [06/02/2021 08:05:33 INFO 140423528630080] Scaling model computed with parameters:
#  {'stdev_label':
# [31895.934]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [3.4896421]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [79380.4]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [5.7799997]
# <NDArray 1 @cpu(0)>}
# [06/02/2021 08:05:34 INFO 140423528630080] nvidia-smi: took 0.036 seconds to run.
# [06/02/2021 08:05:34 INFO 140423528630080] nvidia-smi identified 0 GPUs.
# [06/02/2021 08:05:34 INFO 140423528630080] Number of GPUs being used: 0
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# [06/02/2021 08:05:34 WARNING 140423528630080] Setting num_models to 32.
# #metrics {"StartTime": 1622621134.0872278, "EndTime": 1622621134.0872624, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Total Batches Seen": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-06-02 08:05:34.215] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 128, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622621134.215821, "EndTime": 1622621134.2159152, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8945285511016846, "count": 1, "min": 0.8945285511016846, "max": 0.8945285511016846}}}
#
# #metrics {"StartTime": 1622621134.216011, "EndTime": 1622621134.216034, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9145934009552001, "count": 1, "min": 0.9145934009552001, "max": 0.9145934009552001}}}
#
# #metrics {"StartTime": 1622621134.2160914, "EndTime": 1622621134.2161088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8969591331481933, "count": 1, "min": 0.8969591331481933, "max": 0.8969591331481933}}}
#
# #metrics {"StartTime": 1622621134.2161644, "EndTime": 1622621134.216182, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9135679912567138, "count": 1, "min": 0.9135679912567138, "max": 0.9135679912567138}}}
#
# #metrics {"StartTime": 1622621134.216235, "EndTime": 1622621134.2162516, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7887770366668702, "count": 1, "min": 0.7887770366668702, "max": 0.7887770366668702}}}
#
# #metrics {"StartTime": 1622621134.2163033, "EndTime": 1622621134.2163203, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7973329544067382, "count": 1, "min": 0.7973329544067382, "max": 0.7973329544067382}}}
#
# #metrics {"StartTime": 1622621134.2163727, "EndTime": 1622621134.21639, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8596661376953125, "count": 1, "min": 0.8596661376953125, "max": 0.8596661376953125}}}
#
# #metrics {"StartTime": 1622621134.2164416, "EndTime": 1622621134.2164583, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8193386936187744, "count": 1, "min": 0.8193386936187744, "max": 0.8193386936187744}}}
#
# #metrics {"StartTime": 1622621134.2165103, "EndTime": 1622621134.2165265, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9508654689788818, "count": 1, "min": 0.9508654689788818, "max": 0.9508654689788818}}}
#
# #metrics {"StartTime": 1622621134.2165768, "EndTime": 1622621134.2165933, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8824044704437256, "count": 1, "min": 0.8824044704437256, "max": 0.8824044704437256}}}
#
# #metrics {"StartTime": 1622621134.2166433, "EndTime": 1622621134.2166603, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8891557693481446, "count": 1, "min": 0.8891557693481446, "max": 0.8891557693481446}}}
#
# #metrics {"StartTime": 1622621134.2167118, "EndTime": 1622621134.2167275, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.874226713180542, "count": 1, "min": 0.874226713180542, "max": 0.874226713180542}}}
#
# #metrics {"StartTime": 1622621134.2167785, "EndTime": 1622621134.2167952, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7966775894165039, "count": 1, "min": 0.7966775894165039, "max": 0.7966775894165039}}}
#
# #metrics {"StartTime": 1622621134.2168472, "EndTime": 1622621134.2168627, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8014877033233643, "count": 1, "min": 0.8014877033233643, "max": 0.8014877033233643}}}
#
# #metrics {"StartTime": 1622621134.2169144, "EndTime": 1622621134.2169297, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.795371904373169, "count": 1, "min": 0.795371904373169, "max": 0.795371904373169}}}
#
# #metrics {"StartTime": 1622621134.216981, "EndTime": 1622621134.2169964, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.798916072845459, "count": 1, "min": 0.798916072845459, "max": 0.798916072845459}}}
#
# #metrics {"StartTime": 1622621134.2170491, "EndTime": 1622621134.2170658, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8581383895874023, "count": 1, "min": 0.8581383895874023, "max": 0.8581383895874023}}}
#
# #metrics {"StartTime": 1622621134.2171178, "EndTime": 1622621134.2171335, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9098024272918701, "count": 1, "min": 0.9098024272918701, "max": 0.9098024272918701}}}
#
# #metrics {"StartTime": 1622621134.2171829, "EndTime": 1622621134.217199, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8854198932647706, "count": 1, "min": 0.8854198932647706, "max": 0.8854198932647706}}}
#
# #metrics {"StartTime": 1622621134.2172484, "EndTime": 1622621134.2172654, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.882696361541748, "count": 1, "min": 0.882696361541748, "max": 0.882696361541748}}}
#
# #metrics {"StartTime": 1622621134.217316, "EndTime": 1622621134.2173316, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8169410800933838, "count": 1, "min": 0.8169410800933838, "max": 0.8169410800933838}}}
#
# #metrics {"StartTime": 1622621134.2173805, "EndTime": 1622621134.217396, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8294430732727051, "count": 1, "min": 0.8294430732727051, "max": 0.8294430732727051}}}
#
# #metrics {"StartTime": 1622621134.2174478, "EndTime": 1622621134.2174633, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.806483097076416, "count": 1, "min": 0.806483097076416, "max": 0.806483097076416}}}
#
# #metrics {"StartTime": 1622621134.2175145, "EndTime": 1622621134.2175298, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8643637561798095, "count": 1, "min": 0.8643637561798095, "max": 0.8643637561798095}}}
#
# #metrics {"StartTime": 1622621134.21758, "EndTime": 1622621134.2175944, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8610915470123292, "count": 1, "min": 0.8610915470123292, "max": 0.8610915470123292}}}
#
# #metrics {"StartTime": 1622621134.2176445, "EndTime": 1622621134.2176597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9281379318237305, "count": 1, "min": 0.9281379318237305, "max": 0.9281379318237305}}}
#
# #metrics {"StartTime": 1622621134.2177196, "EndTime": 1622621134.2177365, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9147527980804443, "count": 1, "min": 0.9147527980804443, "max": 0.9147527980804443}}}
#
# #metrics {"StartTime": 1622621134.2177877, "EndTime": 1622621134.217804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9040926551818848, "count": 1, "min": 0.9040926551818848, "max": 0.9040926551818848}}}
#
# #metrics {"StartTime": 1622621134.217855, "EndTime": 1622621134.21787, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9367700004577637, "count": 1, "min": 0.9367700004577637, "max": 0.9367700004577637}}}
#
# #metrics {"StartTime": 1622621134.2179193, "EndTime": 1622621134.2179346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9380142688751221, "count": 1, "min": 0.9380142688751221, "max": 0.9380142688751221}}}
#
# #metrics {"StartTime": 1622621134.217995, "EndTime": 1622621134.2180135, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9642893409729004, "count": 1, "min": 0.9642893409729004, "max": 0.9642893409729004}}}
#
# #metrics {"StartTime": 1622621134.2180746, "EndTime": 1622621134.2180912, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9633904552459717, "count": 1, "min": 0.9633904552459717, "max": 0.9633904552459717}}}
#
# [06/02/2021 08:05:34 INFO 140423528630080] #quality_metric: host=algo-1, epoch=0, train absolute_loss_objective <loss>=0.8945285511016846
# [06/02/2021 08:05:34 INFO 140423528630080] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=absolute_loss_objective, value=0.7887770366668702
# [06/02/2021 08:05:34 INFO 140423528630080] Epoch 0: Loss improved. Updating best model
# [06/02/2021 08:05:34 INFO 140423528630080] Saving model for epoch: 0
# [06/02/2021 08:05:34 INFO 140423528630080] Saved checkpoint to "/tmp/tmpgsyelss9/mx-mod-0000.params"
# [06/02/2021 08:05:34 INFO 140423528630080] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1622621134.0875554, "EndTime": 1622621134.2405493, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 57.0, "count": 1, "min": 57, "max": 57}, "Total Batches Seen": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 08:05:34 INFO 140423528630080] #throughput_metric: host=algo-1, train throughput=169.7786828331138 records/second
# [2021-06-02 08:05:34.371] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 130, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622621134.3716602, "EndTime": 1622621134.3717177, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8557912635803223, "count": 1, "min": 0.8557912635803223, "max": 0.8557912635803223}}}
#
# #metrics {"StartTime": 1622621134.3717842, "EndTime": 1622621134.371797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8758560466766357, "count": 1, "min": 0.8758560466766357, "max": 0.8758560466766357}}}
#
# #metrics {"StartTime": 1622621134.3718276, "EndTime": 1622621134.3718414, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8582218074798584, "count": 1, "min": 0.8582218074798584, "max": 0.8582218074798584}}}
#
# #metrics {"StartTime": 1622621134.371889, "EndTime": 1622621134.3719034, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8748306465148926, "count": 1, "min": 0.8748306465148926, "max": 0.8748306465148926}}}
#
# #metrics {"StartTime": 1622621134.371948, "EndTime": 1622621134.3719618, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4750103092193603, "count": 1, "min": 0.4750103092193603, "max": 0.4750103092193603}}}
#
# #metrics {"StartTime": 1622621134.3720052, "EndTime": 1622621134.37202, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4838706016540527, "count": 1, "min": 0.4838706016540527, "max": 0.4838706016540527}}}
#
# #metrics {"StartTime": 1622621134.3720682, "EndTime": 1622621134.3720827, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.42718470573425293, "count": 1, "min": 0.42718470573425293, "max": 0.42718470573425293}}}
#
# #metrics {"StartTime": 1622621134.3721325, "EndTime": 1622621134.372147, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.568508243560791, "count": 1, "min": 0.568508243560791, "max": 0.568508243560791}}}
#
# #metrics {"StartTime": 1622621134.372196, "EndTime": 1622621134.3722115, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9121278762817383, "count": 1, "min": 0.9121278762817383, "max": 0.9121278762817383}}}
#
# #metrics {"StartTime": 1622621134.3722634, "EndTime": 1622621134.3722794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8436678123474121, "count": 1, "min": 0.8436678123474121, "max": 0.8436678123474121}}}
#
# #metrics {"StartTime": 1622621134.3723304, "EndTime": 1622621134.3723454, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8504190254211426, "count": 1, "min": 0.8504190254211426, "max": 0.8504190254211426}}}
#
# #metrics {"StartTime": 1622621134.3723955, "EndTime": 1622621134.3724113, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8354901599884034, "count": 1, "min": 0.8354901599884034, "max": 0.8354901599884034}}}
#
# #metrics {"StartTime": 1622621134.3724627, "EndTime": 1622621134.3724792, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4834609603881836, "count": 1, "min": 0.4834609603881836, "max": 0.4834609603881836}}}
#
# #metrics {"StartTime": 1622621134.3725297, "EndTime": 1622621134.3725448, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7206231498718262, "count": 1, "min": 0.7206231498718262, "max": 0.7206231498718262}}}
#
# #metrics {"StartTime": 1622621134.3725946, "EndTime": 1622621134.3726103, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.48211127281188965, "count": 1, "min": 0.48211127281188965, "max": 0.48211127281188965}}}
#
# #metrics {"StartTime": 1622621134.3726637, "EndTime": 1622621134.3726797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5502350234985351, "count": 1, "min": 0.5502350234985351, "max": 0.5502350234985351}}}
#
# #metrics {"StartTime": 1622621134.3727293, "EndTime": 1622621134.3727455, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.81951247215271, "count": 1, "min": 0.81951247215271, "max": 0.81951247215271}}}
#
# #metrics {"StartTime": 1622621134.3727949, "EndTime": 1622621134.3728106, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8710953235626221, "count": 1, "min": 0.8710953235626221, "max": 0.8710953235626221}}}
#
# #metrics {"StartTime": 1622621134.3728614, "EndTime": 1622621134.3728776, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8467490863800049, "count": 1, "min": 0.8467490863800049, "max": 0.8467490863800049}}}
#
# #metrics {"StartTime": 1622621134.3729298, "EndTime": 1622621134.3729455, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8440298080444336, "count": 1, "min": 0.8440298080444336, "max": 0.8440298080444336}}}
#
# #metrics {"StartTime": 1622621134.372996, "EndTime": 1622621134.3730118, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5938818550109863, "count": 1, "min": 0.5938818550109863, "max": 0.5938818550109863}}}
#
# #metrics {"StartTime": 1622621134.3730657, "EndTime": 1622621134.3730814, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6028077983856202, "count": 1, "min": 0.6028077983856202, "max": 0.6028077983856202}}}
#
# #metrics {"StartTime": 1622621134.373132, "EndTime": 1622621134.3731484, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5316579484939575, "count": 1, "min": 0.5316579484939575, "max": 0.5316579484939575}}}
#
# #metrics {"StartTime": 1622621134.3732078, "EndTime": 1622621134.3732252, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.46307676792144775, "count": 1, "min": 0.46307676792144775, "max": 0.46307676792144775}}}
#
# #metrics {"StartTime": 1622621134.3732784, "EndTime": 1622621134.3732944, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8644503784179688, "count": 1, "min": 0.8644503784179688, "max": 0.8644503784179688}}}
#
# #metrics {"StartTime": 1622621134.3733456, "EndTime": 1622621134.3733613, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8905514430999756, "count": 1, "min": 0.8905514430999756, "max": 0.8905514430999756}}}
#
# #metrics {"StartTime": 1622621134.373412, "EndTime": 1622621134.3734279, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8799408435821533, "count": 1, "min": 0.8799408435821533, "max": 0.8799408435821533}}}
#
# #metrics {"StartTime": 1622621134.3734813, "EndTime": 1622621134.3734968, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8793697357177734, "count": 1, "min": 0.8793697357177734, "max": 0.8793697357177734}}}
#
# #metrics {"StartTime": 1622621134.3735492, "EndTime": 1622621134.3735662, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9024749660491943, "count": 1, "min": 0.9024749660491943, "max": 0.9024749660491943}}}
#
# #metrics {"StartTime": 1622621134.373622, "EndTime": 1622621134.3736384, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9013331985473633, "count": 1, "min": 0.9013331985473633, "max": 0.9013331985473633}}}
#
# #metrics {"StartTime": 1622621134.373688, "EndTime": 1622621134.3737037, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9040912055969238, "count": 1, "min": 0.9040912055969238, "max": 0.9040912055969238}}}
#
# #metrics {"StartTime": 1622621134.373744, "EndTime": 1622621134.3737578, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9120360469818115, "count": 1, "min": 0.9120360469818115, "max": 0.9120360469818115}}}
#
# [06/02/2021 08:05:34 INFO 140423528630080] #quality_metric: host=algo-1, epoch=1, train absolute_loss_objective <loss>=0.8557912635803223
# [06/02/2021 08:05:34 INFO 140423528630080] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=absolute_loss_objective, value=0.42718470573425293
# [06/02/2021 08:05:34 INFO 140423528630080] Epoch 1: Loss improved. Updating best model
# [06/02/2021 08:05:34 INFO 140423528630080] Saving model for epoch: 1
# [06/02/2021 08:05:34 INFO 140423528630080] Saved checkpoint to "/tmp/tmplgzuantk/mx-mod-0000.params"
# [06/02/2021 08:05:34 INFO 140423528630080] #progress_metric: host=algo-1, completed 40.0 % of epochs
# #metrics {"StartTime": 1622621134.2408817, "EndTime": 1622621134.3828793, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 83.0, "count": 1, "min": 83, "max": 83}, "Total Batches Seen": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 08:05:34 INFO 140423528630080] #throughput_metric: host=algo-1, train throughput=182.92971629195105 records/second
# [2021-06-02 08:05:34.514] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 131, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622621134.5146177, "EndTime": 1622621134.5147007, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8242987442016602, "count": 1, "min": 0.8242987442016602, "max": 0.8242987442016602}}}
#
# #metrics {"StartTime": 1622621134.5147889, "EndTime": 1622621134.5148094, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8442750453948975, "count": 1, "min": 0.8442750453948975, "max": 0.8442750453948975}}}
#
# #metrics {"StartTime": 1622621134.5148666, "EndTime": 1622621134.5148847, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.826729326248169, "count": 1, "min": 0.826729326248169, "max": 0.826729326248169}}}
#
# #metrics {"StartTime": 1622621134.5149393, "EndTime": 1622621134.5149543, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.843249683380127, "count": 1, "min": 0.843249683380127, "max": 0.843249683380127}}}
#
# #metrics {"StartTime": 1622621134.5149999, "EndTime": 1622621134.5150146, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20179739952087403, "count": 1, "min": 0.20179739952087403, "max": 0.20179739952087403}}}
#
# #metrics {"StartTime": 1622621134.5150697, "EndTime": 1622621134.515085, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20509454727172852, "count": 1, "min": 0.20509454727172852, "max": 0.20509454727172852}}}
#
# #metrics {"StartTime": 1622621134.515144, "EndTime": 1622621134.5151608, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.21177355766296388, "count": 1, "min": 0.21177355766296388, "max": 0.21177355766296388}}}
#
# #metrics {"StartTime": 1622621134.5152147, "EndTime": 1622621134.5152302, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2453465962409973, "count": 1, "min": 0.2453465962409973, "max": 0.2453465962409973}}}
#
# #metrics {"StartTime": 1622621134.515283, "EndTime": 1622621134.515299, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8806359672546387, "count": 1, "min": 0.8806359672546387, "max": 0.8806359672546387}}}
#
# #metrics {"StartTime": 1622621134.5153515, "EndTime": 1622621134.5153682, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8120884037017823, "count": 1, "min": 0.8120884037017823, "max": 0.8120884037017823}}}
#
# #metrics {"StartTime": 1622621134.5154197, "EndTime": 1622621134.515434, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8189279842376709, "count": 1, "min": 0.8189279842376709, "max": 0.8189279842376709}}}
#
# #metrics {"StartTime": 1622621134.515482, "EndTime": 1622621134.5154963, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8039108562469482, "count": 1, "min": 0.8039108562469482, "max": 0.8039108562469482}}}
#
# #metrics {"StartTime": 1622621134.515541, "EndTime": 1622621134.5155559, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20357991695404054, "count": 1, "min": 0.20357991695404054, "max": 0.20357991695404054}}}
#
# #metrics {"StartTime": 1622621134.515586, "EndTime": 1622621134.5155938, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3027788162231445, "count": 1, "min": 0.3027788162231445, "max": 0.3027788162231445}}}
#
# #metrics {"StartTime": 1622621134.5156176, "EndTime": 1622621134.5156245, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.20329114198684692, "count": 1, "min": 0.20329114198684692, "max": 0.20329114198684692}}}
#
# #metrics {"StartTime": 1622621134.5156472, "EndTime": 1622621134.5156538, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2087265992164612, "count": 1, "min": 0.2087265992164612, "max": 0.2087265992164612}}}
#
# #metrics {"StartTime": 1622621134.5156767, "EndTime": 1622621134.5156832, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7882349681854248, "count": 1, "min": 0.7882349681854248, "max": 0.7882349681854248}}}
#
# #metrics {"StartTime": 1622621134.5157263, "EndTime": 1622621134.5157402, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8396374797821045, "count": 1, "min": 0.8396374797821045, "max": 0.8396374797821045}}}
#
# #metrics {"StartTime": 1622621134.5157962, "EndTime": 1622621134.5158124, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8154204654693603, "count": 1, "min": 0.8154204654693603, "max": 0.8154204654693603}}}
#
# #metrics {"StartTime": 1622621134.5158734, "EndTime": 1622621134.5158901, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8126184844970703, "count": 1, "min": 0.8126184844970703, "max": 0.8126184844970703}}}
#
# #metrics {"StartTime": 1622621134.515942, "EndTime": 1622621134.5159583, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2620376539230347, "count": 1, "min": 0.2620376539230347, "max": 0.2620376539230347}}}
#
# #metrics {"StartTime": 1622621134.5160158, "EndTime": 1622621134.5160327, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2655638360977173, "count": 1, "min": 0.2655638360977173, "max": 0.2655638360977173}}}
#
# #metrics {"StartTime": 1622621134.516095, "EndTime": 1622621134.516112, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2665154600143433, "count": 1, "min": 0.2665154600143433, "max": 0.2665154600143433}}}
#
# #metrics {"StartTime": 1622621134.5161731, "EndTime": 1622621134.5161939, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33890653610229493, "count": 1, "min": 0.33890653610229493, "max": 0.33890653610229493}}}
#
# #metrics {"StartTime": 1622621134.516259, "EndTime": 1622621134.5162756, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.871562910079956, "count": 1, "min": 0.871562910079956, "max": 0.871562910079956}}}
#
# #metrics {"StartTime": 1622621134.5163364, "EndTime": 1622621134.5163534, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8663798809051514, "count": 1, "min": 0.8663798809051514, "max": 0.8663798809051514}}}
#
# #metrics {"StartTime": 1622621134.5164125, "EndTime": 1622621134.5164297, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8654977321624756, "count": 1, "min": 0.8654977321624756, "max": 0.8654977321624756}}}
#
# #metrics {"StartTime": 1622621134.5164871, "EndTime": 1622621134.5165036, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8751721954345704, "count": 1, "min": 0.8751721954345704, "max": 0.8751721954345704}}}
#
# #metrics {"StartTime": 1622621134.516564, "EndTime": 1622621134.5165806, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8977360439300537, "count": 1, "min": 0.8977360439300537, "max": 0.8977360439300537}}}
#
# #metrics {"StartTime": 1622621134.51663, "EndTime": 1622621134.516645, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8992594337463379, "count": 1, "min": 0.8992594337463379, "max": 0.8992594337463379}}}
#
# #metrics {"StartTime": 1622621134.516706, "EndTime": 1622621134.5167222, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8880680274963378, "count": 1, "min": 0.8880680274963378, "max": 0.8880680274963378}}}
#
# #metrics {"StartTime": 1622621134.5167706, "EndTime": 1622621134.5167847, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.876504545211792, "count": 1, "min": 0.876504545211792, "max": 0.876504545211792}}}
#
# [06/02/2021 08:05:34 INFO 140423528630080] #quality_metric: host=algo-1, epoch=2, train absolute_loss_objective <loss>=0.8242987442016602
# [06/02/2021 08:05:34 INFO 140423528630080] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=absolute_loss_objective, value=0.20179739952087403
# [06/02/2021 08:05:34 INFO 140423528630080] Epoch 2: Loss improved. Updating best model
# [06/02/2021 08:05:34 INFO 140423528630080] Saving model for epoch: 2
# [06/02/2021 08:05:34 INFO 140423528630080] Saved checkpoint to "/tmp/tmpnt8wnnh7/mx-mod-0000.params"
# [06/02/2021 08:05:34 INFO 140423528630080] #progress_metric: host=algo-1, completed 60.0 % of epochs
# #metrics {"StartTime": 1622621134.3831608, "EndTime": 1622621134.5263462, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 109.0, "count": 1, "min": 109, "max": 109}, "Total Batches Seen": {"sum": 25.0, "count": 1, "min": 25, "max": 25}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 08:05:34 INFO 140423528630080] #throughput_metric: host=algo-1, train throughput=181.38707375613552 records/second
# [2021-06-02 08:05:34.627] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 100, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622621134.6273317, "EndTime": 1622621134.6274238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7938915824890137, "count": 1, "min": 0.7938915824890137, "max": 0.7938915824890137}}}
#
# #metrics {"StartTime": 1622621134.6275134, "EndTime": 1622621134.6275346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8135607719421387, "count": 1, "min": 0.8135607719421387, "max": 0.8135607719421387}}}
#
# #metrics {"StartTime": 1622621134.627592, "EndTime": 1622621134.6276104, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7963221836090087, "count": 1, "min": 0.7963221836090087, "max": 0.7963221836090087}}}
#
# #metrics {"StartTime": 1622621134.6276631, "EndTime": 1622621134.6276796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8125353431701661, "count": 1, "min": 0.8125353431701661, "max": 0.8125353431701661}}}
#
# #metrics {"StartTime": 1622621134.627734, "EndTime": 1622621134.6277509, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.300389199256897, "count": 1, "min": 0.300389199256897, "max": 0.300389199256897}}}
#
# #metrics {"StartTime": 1622621134.6278114, "EndTime": 1622621134.6278288, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2947694158554077, "count": 1, "min": 0.2947694158554077, "max": 0.2947694158554077}}}
#
# #metrics {"StartTime": 1622621134.6278992, "EndTime": 1622621134.6279168, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.34739300966262815, "count": 1, "min": 0.34739300966262815, "max": 0.34739300966262815}}}
#
# #metrics {"StartTime": 1622621134.6279733, "EndTime": 1622621134.62799, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.31880349159240723, "count": 1, "min": 0.31880349159240723, "max": 0.31880349159240723}}}
#
# #metrics {"StartTime": 1622621134.6280422, "EndTime": 1622621134.6280596, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.850230712890625, "count": 1, "min": 0.850230712890625, "max": 0.850230712890625}}}
#
# #metrics {"StartTime": 1622621134.6281128, "EndTime": 1622621134.62813, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7813770198822021, "count": 1, "min": 0.7813770198822021, "max": 0.7813770198822021}}}
#
# #metrics {"StartTime": 1622621134.6281817, "EndTime": 1622621134.6281986, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7885236358642578, "count": 1, "min": 0.7885236358642578, "max": 0.7885236358642578}}}
#
# ...
# [06/02/2021 08:05:34 INFO 140423528630080] #progress_metric: host=algo-1, completed 80.0 % of epochs
# #metrics {"StartTime": 1622621134.5267124, "EndTime": 1622621134.638876, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 135.0, "count": 1, "min": 135, "max": 135}, "Total Batches Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 08:05:34 INFO 140423528630080] #throughput_metric: host=algo-1, train throughput=231.49240259657554 records/second
# [2021-06-02 08:05:34.733] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 12, "duration": 93, "num_examples": 6, "num_bytes": 1248}
# #metrics {"StartTime": 1622621134.7331748, "EndTime": 1622621134.7332597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7723214626312256, "count": 1, "min": 0.7723214626312256, "max": 0.7723214626312256}}}
#
# #metrics {"StartTime": 1622621134.7333498, "EndTime": 1622621134.733372, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7900911426544189, "count": 1, "min": 0.7900911426544189, "max": 0.7900911426544189}}}
#
# #metrics {"StartTime": 1622621134.7334282, "EndTime": 1622621134.7334454, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7745308399200439, "count": 1, "min": 0.7745308399200439, "max": 0.7745308399200439}}}
#
# #metrics {"StartTime": 1622621134.7334912, "EndTime": 1622621134.7335062, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7891590690612793, "count": 1, "min": 0.7891590690612793, "max": 0.7891590690612793}}}
#
# #metrics {"StartTime": 1622621134.7335632, "EndTime": 1622621134.7335808, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2534684824943543, "count": 1, "min": 0.2534684824943543, "max": 0.2534684824943543}}}
#
# #metrics {"StartTime": 1622621134.7336373, "EndTime": 1622621134.7336538, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2497752094268799, "count": 1, "min": 0.2497752094268799, "max": 0.2497752094268799}}}
#
# #metrics {"StartTime": 1622621134.7337058, "EndTime": 1622621134.7337227, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3031576108932495, "count": 1, "min": 0.3031576108932495, "max": 0.3031576108932495}}}
#
# #metrics {"StartTime": 1622621134.733776, "EndTime": 1622621134.7337923, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.22437820196151734, "count": 1, "min": 0.22437820196151734, "max": 0.22437820196151734}}}
#
# #metrics {"StartTime": 1622621134.7338479, "EndTime": 1622621134.733865, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.825195255279541, "count": 1, "min": 0.825195255279541, "max": 0.825195255279541}}}
#
# #metrics {"StartTime": 1622621134.7339165, "EndTime": 1622621134.7339327, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7608409309387207, "count": 1, "min": 0.7608409309387207, "max": 0.7608409309387207}}}
#
# #metrics {"StartTime": 1622621134.733984, "EndTime": 1622621134.7340004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7674464607238769, "count": 1, "min": 0.7674464607238769, "max": 0.7674464607238769}}}
#
# #metrics {"StartTime": 1622621134.73405, "EndTime": 1622621134.734066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7534078311920166, "count": 1, "min": 0.7534078311920166, "max": 0.7534078311920166}}}
#
# #metrics {"StartTime": 1622621134.7341225, "EndTime": 1622621134.734139, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.24247640371322632, "count": 1, "min": 0.24247640371322632, "max": 0.24247640371322632}}}
#
# #metrics {"StartTime": 1622621134.7341897, "EndTime": 1622621134.7342062, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.29072519063949587, "count": 1, "min": 0.29072519063949587, "max": 0.29072519063949587}}}
#
# #metrics {"StartTime": 1622621134.7342641, "EndTime": 1622621134.734281, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.24336956262588502, "count": 1, "min": 0.24336956262588502, "max": 0.24336956262588502}}}
#
# #metrics {"StartTime": 1622621134.7343314, "EndTime": 1622621134.7343469, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.21867279291152955, "count": 1, "min": 0.21867279291152955, "max": 0.21867279291152955}}}
#
# #metrics {"StartTime": 1622621134.7343976, "EndTime": 1622621134.734414, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7396121978759765, "count": 1, "min": 0.7396121978759765, "max": 0.7396121978759765}}}
#
# #metrics {"StartTime": 1622621134.7344766, "EndTime": 1622621134.7344935, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7865690803527832, "count": 1, "min": 0.7865690803527832, "max": 0.7865690803527832}}}
#
# #metrics {"StartTime": 1622621134.7345502, "EndTime": 1622621134.734592, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7650337886810302, "count": 1, "min": 0.7650337886810302, "max": 0.7650337886810302}}}
#
# #metrics {"StartTime": 1622621134.7346475, "EndTime": 1622621134.7346642, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7621239376068115, "count": 1, "min": 0.7621239376068115, "max": 0.7621239376068115}}}
#
# #metrics {"StartTime": 1622621134.734719, "EndTime": 1622621134.7347357, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4365283679962158, "count": 1, "min": 0.4365283679962158, "max": 0.4365283679962158}}}
#
# #metrics {"StartTime": 1622621134.7347918, "EndTime": 1622621134.7348082, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4343521785736084, "count": 1, "min": 0.4343521785736084, "max": 0.4343521785736084}}}
#
# #metrics {"StartTime": 1622621134.7348597, "EndTime": 1622621134.7348764, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3786530637741089, "count": 1, "min": 0.3786530637741089, "max": 0.3786530637741089}}}
#
# #metrics {"StartTime": 1622621134.7349348, "EndTime": 1622621134.7349517, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3593438577651977, "count": 1, "min": 0.3593438577651977, "max": 0.3593438577651977}}}
#
# #metrics {"StartTime": 1622621134.7350023, "EndTime": 1622621134.735018, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.870873441696167, "count": 1, "min": 0.870873441696167, "max": 0.870873441696167}}}
#
# #metrics {"StartTime": 1622621134.735068, "EndTime": 1622621134.7350848, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8533285999298096, "count": 1, "min": 0.8533285999298096, "max": 0.8533285999298096}}}
#
# #metrics {"StartTime": 1622621134.735144, "EndTime": 1622621134.7351613, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8628853988647461, "count": 1, "min": 0.8628853988647461, "max": 0.8628853988647461}}}
#
# #metrics {"StartTime": 1622621134.7352116, "EndTime": 1622621134.735227, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8580431938171387, "count": 1, "min": 0.8580431938171387, "max": 0.8580431938171387}}}
#
# #metrics {"StartTime": 1622621134.7352748, "EndTime": 1622621134.7352903, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.9994428443908692, "count": 1, "min": 0.9994428443908692, "max": 0.9994428443908692}}}
#
# #metrics {"StartTime": 1622621134.7353513, "EndTime": 1622621134.735369, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 1.0013238525390624, "count": 1, "min": 1.0013238525390624, "max": 1.0013238525390624}}}
#
# #metrics {"StartTime": 1622621134.7354305, "EndTime": 1622621134.7354474, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8635519218444824, "count": 1, "min": 0.8635519218444824, "max": 0.8635519218444824}}}
#
# #metrics {"StartTime": 1622621134.735505, "EndTime": 1622621134.7355223, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8558250045776368, "count": 1, "min": 0.8558250045776368, "max": 0.8558250045776368}}}
#
# [06/02/2021 08:05:34 INFO 140423528630080] #quality_metric: host=algo-1, epoch=4, train absolute_loss_objective <loss>=0.7723214626312256
# [06/02/2021 08:05:34 INFO 140423528630080] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=absolute_loss_objective, value=0.21867279291152955
# [06/02/2021 08:05:34 INFO 140423528630080] Saving model for epoch: 4
# [06/02/2021 08:05:34 INFO 140423528630080] Saved checkpoint to "/tmp/tmp191cddqo/mx-mod-0000.params"
# [06/02/2021 08:05:34 INFO 140423528630080] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1622621134.6391828, "EndTime": 1622621134.7438555, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 161.0, "count": 1, "min": 161, "max": 161}, "Total Batches Seen": {"sum": 37.0, "count": 1, "min": 37, "max": 37}, "Max Records Seen Between Resets": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Batches Seen Between Resets": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Batches Since Last Reset": {"sum": 6.0, "count": 1, "min": 6, "max": 6}}}
#
# [06/02/2021 08:05:34 INFO 140423528630080] #throughput_metric: host=algo-1, train throughput=248.06680512366728 records/second
# [06/02/2021 08:05:34 WARNING 140423528630080] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/02/2021 08:05:34 WARNING 140423528630080] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-06-02 08:05:34.744] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 14, "duration": 0, "num_examples": 1, "num_bytes": 240}
# [2021-06-02 08:05:34.753] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 16, "duration": 6, "num_examples": 6, "num_bytes": 1248}
# [06/02/2021 08:05:34 INFO 140423528630080] #train_score (algo-1) : ('absolute_loss_objective', 8610.715745192309)
# [06/02/2021 08:05:34 INFO 140423528630080] #train_score (algo-1) : ('mse', 103096993.23076923)
# [06/02/2021 08:05:34 INFO 140423528630080] #train_score (algo-1) : ('absolute_loss', 8610.715745192309)
# [06/02/2021 08:05:34 INFO 140423528630080] #quality_metric: host=algo-1, train absolute_loss_objective <loss>=8610.715745192309
# [06/02/2021 08:05:34 INFO 140423528630080] #quality_metric: host=algo-1, train mse <loss>=103096993.23076923
# [06/02/2021 08:05:34 INFO 140423528630080] #quality_metric: host=algo-1, train absolute_loss <loss>=8610.715745192309
# [06/02/2021 08:05:34 INFO 140423528630080] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 1, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [06/02/2021 08:05:34 INFO 140423528630080] Saved checkpoint to "/tmp/tmp7pqs88wn/mx-mod-0000.params"
# [06/02/2021 08:05:34 INFO 140423528630080] Test data is not provided.
# #metrics {"StartTime": 1622621133.8587985, "EndTime": 1622621134.759402, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 227.45537757873535, "count": 1, "min": 227.45537757873535, "max": 227.45537757873535}, "epochs": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "check_early_stopping.time": {"sum": 5.301237106323242, "count": 5, "min": 0.2460479736328125, "max": 1.6927719116210938}, "update.time": {"sum": 634.4799995422363, "count": 5, "min": 102.04792022705078, "max": 143.17870140075684}, "finalize.time": {"sum": 10.268688201904297, "count": 1, "min": 10.268688201904297, "max": 10.268688201904297}, "setuptime": {"sum": 24.170398712158203, "count": 1, "min": 24.170398712158203, "max": 24.170398712158203}, "totaltime": {"sum": 1153.7129878997803, "count": 1, "min": 1153.7129878997803, "max": 1153.7129878997803}}}
#
#
# 2021-06-02 08:05:51 Completed - Training job completed
# Training seconds: 46
# Billable seconds: 9
# Managed Spot Training savings: 80.4%

# %% [markdown]
# # TASK #8: DEPLOY AND TEST THE TRAINED LINEAR LEARNER MODEL

# %%
# Deploying the model to perform inference 

linear_regressor = linear.deploy(initial_instance_count = 1,
                                          instance_type = 'ml.m4.xlarge')
# Out:
# -------------!

# %%
from sagemaker.predictor import csv_serializer, json_deserializer

# Content type overrides the data that will be passed to the deployed model, since the deployed model expects data in text/csv format.

# Serializer accepts a single argument, the input data, and returns a sequence of bytes in the specified content type

# Deserializer accepts two arguments, the result data and the response content type, and return a sequence of bytes in the specified content type.

# Reference: https://sagemaker.readthedocs.io/en/stable/predictors.html

# linear_regressor.content_type = 'text/csv'
linear_regressor.serializer = csv_serializer
linear_regressor.deserializer = json_deserializer

# %%
# making prediction on the test data

result = linear_regressor.predict(X_test)
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
result # results are in Json format
# Out:
# {'predictions': [{'score': 115379.3828125},
#   {'score': 70049.8515625},
#   {'score': 82090.515625},
#   {'score': 84215.328125},
#   {'score': 71466.40625},
#   {'score': 54467.828125},
#   {'score': 125295.21875},
#   {'score': 121045.578125},
#   {'score': 60134.015625}]}

# %%
# Since the result is in json format, we access the scores by iterating through the scores in the predictions

predictions = np.array([r['score'] for r in result['predictions']])

# %%
predictions
# Out:
# array([115379.3828125,  70049.8515625,  82090.515625 ,  84215.328125 ,
#         71466.40625  ,  54467.828125 , 125295.21875  , 121045.578125 ,
#         60134.015625 ])

# %%
predictions.shape
# Out:
# (9,)

# %%
# VISUALIZE TEST SET RESULTS
plt.scatter(X_test, y_test, color = 'gray')
plt.plot(X_test, predictions, color = 'red')
plt.xlabel('Years of Experience (Testing Dataset)')
plt.ylabel('salary')
plt.title('Salary vs. Years of Experience')
# Out:
# Text(0.5, 1.0, 'Salary vs. Years of Experience')

# %%
# Delete the end-point

linear_regressor.delete_endpoint()

# %% [markdown]
# # EXCELLENT JOB! NOW YOU'RE FAMILIAR WITH SAGEMAKER LINEAR LEARNER, YOU SHOULD BE PROUD OF YOUR NEWLY ACQUIRED SKILLS
